# %% [markdown]
# ## WeatherPy: Visualizing weather based on Latitude
# March 2, 2019
# Scott McEachern

# %%
#-- Import Libraries
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import requests
import datetime

# OpenWeatherMap API Key located in secrets.py; .gitignore prevents secrets.py from push to GitHub
from secrets import api_key

# citipy library to lookup city name based on lat/long; 
# require installation of dependencies with: pip install citipy
from citipy import citipy

# %%
#-- Generate List of Cities

# Number of random locations to calculate
numRandomLocations = 4000

# Total number of cities to get weather information from API
numCities = 1000


#- Create Random Coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=numRandomLocations)
lngs = np.random.uniform(low=-180.000, high=180.000, size=numRandomLocations)


#- Merge into Zip
lat_lngs = zip(lats, lngs)


#- Find City Name
cityNames = []

for lat_lng in lat_lngs:
    
    # Get nearest city
    cityName = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # Determine new city name
    if (cityName not in cityNames):
        cityNames.append(cityName)

        # Check if reached number of cities used with analysis
        if (len(cityNames) == numCities):
            break

            
#- Information on cities
print(f'Created list of city names; total {len(cityNames)}')
# Out:
# Created list of city names; total 1000

# %%
def getWeatherForCity(cityName):
    ''' Queries the OpenWeatherData API to get the current weather conditions for the city name provided.
    Exceptions are captured and when exception, metadata printed to console.
    
    Accepts : cityName (str) Name of the city to search to get current weather information for
    
    Returns : List - contains metadata from the API; returns None when exception or not 200 response
                0 - (str) City Name
                1 - (str) Country Code
                2 - (num) Latitude
                3 - (num) Longitude
                4 - (num) Max Temperature - F
                5 - (num) Windspeed - MPH
                6 - (num) Humidity - %
                7 - (num) Cloudiness - %
    '''
    
    try:
        
        #- Prepare URL
        baseWeatherUrl = "http://api.openweathermap.org/data/2.5/weather"
        unitFormat = "imperial"
        
        queryUrl = f"{baseWeatherUrl}?q={cityName}&units={unitFormat}&appid={api_key}"
        
        
        #- Get Weather from API
        response = requests.get(queryUrl)
        
        
        #- Check Response
        cityWeather = []
        
        if (response.status_code == requests.codes.ok):
            
            # Get Json from Response
            responseJson = response.json()
            
            
            # Get Weather Information
            cityWeather.append(responseJson['name'])
            cityWeather.append(responseJson['sys']['country'])
            
            cityWeather.append(responseJson['coord']['lat'])
            cityWeather.append(responseJson['coord']['lon'])
            
            cityWeather.append(responseJson['main']['temp_max'])
            cityWeather.append(responseJson['wind']['speed'])
                        
            cityWeather.append(responseJson['main']['humidity'])
            cityWeather.append(responseJson['clouds']['all'])
        
        else:
            #- Response not valid; return None
            return
        
        
        return cityWeather
        
    except Exception as e:
        print(f"   Exception getting weather from API. City: {cityName} Error Type: {type(e)} Info: {e}")

# %%
##- Get Weather for City

#- Prepare Dictionary to store results
weatherData = {
    'City': [],
    'Country': [],
    'Latitude' : [],
    'Longitude' : [],
    'Temperature' : [],
    'WindSpeed' : [],
    'Humidity' : [],
    'Cloudiness': [],
    }


#- Display Message
print("> Start data retrieval")


#- Get Weather Information
errorCounter = 0
counter = 0

for cityName in cityNames:
    
    # Progress Message
    counter += 1
    
    print(f"Processing: {counter} of {len(cityNames)} - {cityName.title()}")
    
    
    # Get Weather for City
    cityInfo = getWeatherForCity(cityName)
    
    
    # Check Results from API
    if (cityInfo != None):
        weatherData['City'].append(cityInfo[0])
        weatherData['Country'].append(cityInfo[1])
        weatherData['Latitude'].append(cityInfo[2])
        weatherData['Longitude'].append(cityInfo[3])
        weatherData['Temperature'].append(cityInfo[4])
        weatherData['WindSpeed'].append(cityInfo[5])
        weatherData['Humidity'].append(cityInfo[6])
        weatherData['Cloudiness'].append(cityInfo[7])
        
    else:
        print(f"   Unable to get weather information for city: {cityName.title()}")
        errorCounter +=1
    
    
#- Display Message
print(" ")
print(f"Completed getting data. Total Cities: {len(weatherData['City'])}  Error Cities: {errorCounter}")
# Out:
# > Start data retrieval
# Processing: 1 of 1000 - Tuktoyaktuk
# Processing: 2 of 1000 - Saint-Francois
# Processing: 3 of 1000 - Hobart
# Processing: 4 of 1000 - Albany
# Processing: 5 of 1000 - Khatanga
# Processing: 6 of 1000 - Dolores
# Processing: 7 of 1000 - Barentsburg
#    Unable to get weather information for city: Barentsburg
# Processing: 8 of 1000 - Mar Del Plata
# Processing: 9 of 1000 - Nizhneyansk
#    Unable to get weather information for city: Nizhneyansk
# Processing: 10 of 1000 - Mataura
# Processing: 11 of 1000 - Rikitea
# Processing: 12 of 1000 - Yarim
# Processing: 13 of 1000 - Sao Filipe
# Processing: 14 of 1000 - Tadine
# Processing: 15 of 1000 - Wanaka
# Processing: 16 of 1000 - Berbera
#    Unable to get weather information for city: Berbera
# Processing: 17 of 1000 - Malwan
#    Unable to get weather information for city: Malwan
# Processing: 18 of 1000 - Labuhan
# Processing: 19 of 1000 - Adeje
# Processing: 20 of 1000 - New Norfolk
# Processing: 21 of 1000 - Bonthe
# Processing: 22 of 1000 - Concordia
# Processing: 23 of 1000 - Catalina
# Processing: 24 of 1000 - Yulara
# Processing: 25 of 1000 - Hilo
# Processing: 26 of 1000 - Vaitupu
#    Unable to get weather information for city: Vaitupu
# Processing: 27 of 1000 - Ushuaia
# Processing: 28 of 1000 - Saskylakh
# Processing: 29 of 1000 - Hermanus
# Processing: 30 of 1000 - Panacan
# Processing: 31 of 1000 - Busselton
# Processing: 32 of 1000 - Cherskiy
# Processing: 33 of 1000 - Vaini
# Processing: 34 of 1000 - Georgetown
# Processing: 35 of 1000 - Louisbourg
#    Unable to get weather information for city: Louisbourg
# Processing: 36 of 1000 - Tangjiazhuang
# Processing: 37 of 1000 - Broome
# Processing: 38 of 1000 - Balkanabat
# Processing: 39 of 1000 - Broken Hill
# Processing: 40 of 1000 - Lagoa
# Processing: 41 of 1000 - Bethel
# Processing: 42 of 1000 - Puerto Madero
# Processing: 43 of 1000 - Ponta Do Sol
# Processing: 44 of 1000 - Katima Mulilo
# Processing: 45 of 1000 - Karpogory
# Processing: 46 of 1000 - Punta Arenas
# Processing: 47 of 1000 - Taolanaro
#    Unable to get weather information for city: Taolanaro
# Processing: 48 of 1000 - Mareeba
# Processing: 49 of 1000 - Muzhi
# Processing: 50 of 1000 - Salalah
# Processing: 51 of 1000 - Meulaboh
# Processing: 52 of 1000 - Jacupiranga
# Processing: 53 of 1000 - Esperance
# Processing: 54 of 1000 - Nagar Karnul
# Processing: 55 of 1000 - Bereznik
# Processing: 56 of 1000 - Mendahara
#    Unable to get weather information for city: Mendahara
# Processing: 57 of 1000 - Ust-Kamchatsk
#    Unable to get weather information for city: Ust-Kamchatsk
# Processing: 58 of 1000 - Bredasdorp
# Processing: 59 of 1000 - Saint-Augustin
# Processing: 60 of 1000 - Norman Wells
# Processing: 61 of 1000 - Boralday
# Processing: 62 of 1000 - Cape Town
# Processing: 63 of 1000 - Road Town
# Processing: 64 of 1000 - Kodiak
# Processing: 65 of 1000 - Illoqqortoormiut
#    Unable to get weather information for city: Illoqqortoormiut
# Processing: 66 of 1000 - Avarua
# Processing: 67 of 1000 - Chuy
# Processing: 68 of 1000 - Ndjole
# Processing: 69 of 1000 - Havoysund
# Processing: 70 of 1000 - Tsihombe
#    Unable to get weather information for city: Tsihombe
# Processing: 71 of 1000 - Belushya Guba
#    Unable to get weather information for city: Belushya Guba
# Processing: 72 of 1000 - Porto Novo
# Processing: 73 of 1000 - Codrington
# Processing: 74 of 1000 - Saint-Philippe
# Processing: 75 of 1000 - Amderma
#    Unable to get weather information for city: Amderma
# Processing: 76 of 1000 - Lebu
# Processing: 77 of 1000 - Port Elizabeth
# Processing: 78 of 1000 - Barrow
# Processing: 79 of 1000 - Talnakh
# Processing: 80 of 1000 - Thurso
# Processing: 81 of 1000 - Qaanaaq
# Processing: 82 of 1000 - Hithadhoo
# Processing: 83 of 1000 - Baijiantan
# Processing: 84 of 1000 - Muromtsevo
# Processing: 85 of 1000 - San Patricio
# Processing: 86 of 1000 - Cabo San Lucas
# Processing: 87 of 1000 - Katsuura
# Processing: 88 of 1000 - Jamestown
# Processing: 89 of 1000 - East London
# Processing: 90 of 1000 - Guerrero Negro
# Processing: 91 of 1000 - Balkhash
# Processing: 92 of 1000 - Coquimbo
# Processing: 93 of 1000 - Nome
# Processing: 94 of 1000 - Ambunti
# Processing: 95 of 1000 - Qingdao
# Processing: 96 of 1000 - Mahebourg
# Processing: 97 of 1000 - Thompson
# Processing: 98 of 1000 - Sorland
# Processing: 99 of 1000 - Tairua
# Processing: 100 of 1000 - Kununurra
# Processing: 101 of 1000 - Castro
# Processing: 102 of 1000 - Marawi
# Processing: 103 of 1000 - Atuona
# Processing: 104 of 1000 - Hasaki
# Processing: 105 of 1000 - Caravelas
# Processing: 106 of 1000 - Chase
# Processing: 107 of 1000 - Coihaique
# Processing: 108 of 1000 - Kyaikto
# Processing: 109 of 1000 - Nanortalik
# Processing: 110 of 1000 - Luderitz
# Processing: 111 of 1000 - Kushima
# Processing: 112 of 1000 - Arraial Do Cabo
# Processing: 113 of 1000 - Sentyabrskiy
#    Unable to get weather information for city: Sentyabrskiy
# Processing: 114 of 1000 - Puerto Ayora
# Processing: 115 of 1000 - Hanmer Springs
# Processing: 116 of 1000 - Upata
# Processing: 117 of 1000 - Hay River
# Processing: 118 of 1000 - Kapaa
# Processing: 119 of 1000 - Banda Aceh
# Processing: 120 of 1000 - Viedma
# Processing: 121 of 1000 - Dikson
# Processing: 122 of 1000 - Buin
# Processing: 123 of 1000 - Umba
# Processing: 124 of 1000 - Port Alfred
# Processing: 125 of 1000 - Chokurdakh
# Processing: 126 of 1000 - Buta
# Processing: 127 of 1000 - Kristinehamn
# Processing: 128 of 1000 - Faanui
# Processing: 129 of 1000 - Kruisfontein
# Processing: 130 of 1000 - Tambura
#    Unable to get weather information for city: Tambura
# Processing: 131 of 1000 - Kashi
#    Unable to get weather information for city: Kashi
# Processing: 132 of 1000 - Attawapiskat
#    Unable to get weather information for city: Attawapiskat
# Processing: 133 of 1000 - Torbay
# Processing: 134 of 1000 - Vila Velha
# Processing: 135 of 1000 - Sabang
# Processing: 136 of 1000 - Nikolskoye
# Processing: 137 of 1000 - Victoria
# Processing: 138 of 1000 - Paramonga
# Processing: 139 of 1000 - San Cristobal
# Processing: 140 of 1000 - Acapulco
# Processing: 141 of 1000 - Pingzhuang
#    Unable to get weather information for city: Pingzhuang
# Processing: 142 of 1000 - Pevek
# Processing: 143 of 1000 - Benalla
# Processing: 144 of 1000 - Itarema
# Processing: 145 of 1000 - Cortez
# Processing: 146 of 1000 - Deputatskiy
# Processing: 147 of 1000 - Graaff-Reinet
# Processing: 148 of 1000 - Mys Shmidta
#    Unable to get weather information for city: Mys Shmidta
# Processing: 149 of 1000 - Kavaratti
# Processing: 150 of 1000 - Ribeira Grande
# Processing: 151 of 1000 - Bosaso
# Processing: 152 of 1000 - Saldanha
# Processing: 153 of 1000 - Winslow
# Processing: 154 of 1000 - Nemuro
# Processing: 155 of 1000 - Kumano
# Processing: 156 of 1000 - Acajutla
# Processing: 157 of 1000 - Tura
# Processing: 158 of 1000 - Inuvik
# Processing: 159 of 1000 - Shimoda
# Processing: 160 of 1000 - Ancud
# Processing: 161 of 1000 - Roma
# Processing: 162 of 1000 - Pitimbu
# Processing: 163 of 1000 - Bambous Virieux
# Processing: 164 of 1000 - Harper
# Processing: 165 of 1000 - Morgan City
# Processing: 166 of 1000 - Atka
#    Unable to get weather information for city: Atka
# Processing: 167 of 1000 - Halifax
# Processing: 168 of 1000 - Touros
# Processing: 169 of 1000 - Egvekinot
# Processing: 170 of 1000 - Grado
# Processing: 171 of 1000 - Vokhtoga
# Processing: 172 of 1000 - Kristiansund
# Processing: 173 of 1000 - Mitu
# Processing: 174 of 1000 - Aklavik
# Processing: 175 of 1000 - Ahuimanu
# Processing: 176 of 1000 - Togur
# Processing: 177 of 1000 - Salisbury
# Processing: 178 of 1000 - San Quintin
# Processing: 179 of 1000 - Oshogbo
#    Unable to get weather information for city: Oshogbo
# Processing: 180 of 1000 - Los Llanos De Aridane
# Processing: 181 of 1000 - Saint George
# Processing: 182 of 1000 - Barbar
#    Unable to get weather information for city: Barbar
# Processing: 183 of 1000 - Pacific Grove
# Processing: 184 of 1000 - Longyearbyen
# Processing: 185 of 1000 - Kaitangata
# Processing: 186 of 1000 - Saquarema
# Processing: 187 of 1000 - Quatre Cocos
# Processing: 188 of 1000 - Gat
# Processing: 189 of 1000 - Preobrazheniye
# Processing: 190 of 1000 - Wadena
# Processing: 191 of 1000 - Vilyuysk
# Processing: 192 of 1000 - Manaure
# Processing: 193 of 1000 - Camocim
# Processing: 194 of 1000 - Yar-Sale
# Processing: 195 of 1000 - Mrirt
#    Unable to get weather information for city: Mrirt
# Processing: 196 of 1000 - Okhotsk
# Processing: 197 of 1000 - Pisco
# Processing: 198 of 1000 - Butaritari
# Processing: 199 of 1000 - Upernavik
# Processing: 200 of 1000 - Rancho Palos Verdes
# Processing: 201 of 1000 - Alice Springs
# Processing: 202 of 1000 - Seymchan
# Processing: 203 of 1000 - Hamilton
# Processing: 204 of 1000 - Adrar
# Processing: 205 of 1000 - Sonoita
# Processing: 206 of 1000 - Ous
# Processing: 207 of 1000 - Sept-Iles
# Processing: 208 of 1000 - Catamarca
#    Unable to get weather information for city: Catamarca
# Processing: 209 of 1000 - Tiksi
# Processing: 210 of 1000 - Tuatapere
# Processing: 211 of 1000 - Shamgarh
# Processing: 212 of 1000 - Kahului
# Processing: 213 of 1000 - Summerside
# Processing: 214 of 1000 - Sao Gabriel Da Cachoeira
# Processing: 215 of 1000 - Douglas
# Processing: 216 of 1000 - Dubbo
# Processing: 217 of 1000 - Desnogorsk
# Processing: 218 of 1000 - Mount Gambier
# Processing: 219 of 1000 - Fare
# Processing: 220 of 1000 - Iqaluit
# Processing: 221 of 1000 - Geraldton
# Processing: 222 of 1000 - Poum
# Processing: 223 of 1000 - Renukut
# Processing: 224 of 1000 - Rawa Mazowiecka
# Processing: 225 of 1000 - Biak
# Processing: 226 of 1000 - Tezu
# Processing: 227 of 1000 - Naze
# Processing: 228 of 1000 - Klaksvik
# Processing: 229 of 1000 - Bluff
# Processing: 230 of 1000 - Port Blair
# Processing: 231 of 1000 - Leningradskiy
# Processing: 232 of 1000 - Kayes
# Processing: 233 of 1000 - Airai
# Processing: 234 of 1000 - Altamont
# Processing: 235 of 1000 - Pattaya
# Processing: 236 of 1000 - Udimskiy
# Processing: 237 of 1000 - Port-Gentil
# Processing: 238 of 1000 - Taksimo
# Processing: 239 of 1000 - Prince Rupert
# Processing: 240 of 1000 - Clyde River
# Processing: 241 of 1000 - Opuwo
# Processing: 242 of 1000 - Manama
# Processing: 243 of 1000 - Verkhoyansk
# Processing: 244 of 1000 - The Pas
# Processing: 245 of 1000 - Saleaula
#    Unable to get weather information for city: Saleaula
# Processing: 246 of 1000 - Yerbogachen
# Processing: 247 of 1000 - Buala
# Processing: 248 of 1000 - Takoradi
# Processing: 249 of 1000 - Svay Rieng
# Processing: 250 of 1000 - Play Cu
#    Unable to get weather information for city: Play Cu
# Processing: 251 of 1000 - Geresk
#    Unable to get weather information for city: Geresk
# Processing: 252 of 1000 - Lompoc
# Processing: 253 of 1000 - Vostok
# Processing: 254 of 1000 - Dzhusaly
#    Unable to get weather information for city: Dzhusaly
# Processing: 255 of 1000 - Beyla
# Processing: 256 of 1000 - Sinnamary
# Processing: 257 of 1000 - El Balyana
#    Unable to get weather information for city: El Balyana
# Processing: 258 of 1000 - Ixtapa
# Processing: 259 of 1000 - Chubbuck
# Processing: 260 of 1000 - Turukhansk
# Processing: 261 of 1000 - Saint-Pierre
# Processing: 262 of 1000 - Xining
# Processing: 263 of 1000 - Yanan
#    Unable to get weather information for city: Yanan
# Processing: 264 of 1000 - Farah
# Processing: 265 of 1000 - Dunedin
# Processing: 266 of 1000 - Northam
# Processing: 267 of 1000 - Lasa
# Processing: 268 of 1000 - Maniitsoq
# Processing: 269 of 1000 - Maanshan
# Processing: 270 of 1000 - Severo-Kurilsk
# Processing: 271 of 1000 - San Carlos
# Processing: 272 of 1000 - Tasiilaq
# Processing: 273 of 1000 - Luancheng
# Processing: 274 of 1000 - Akdepe
# Processing: 275 of 1000 - Conceicao Do Araguaia
# Processing: 276 of 1000 - Okha
# Processing: 277 of 1000 - Campbell River
# Processing: 278 of 1000 - Ahualulco
# Processing: 279 of 1000 - Karaul
#    Unable to get weather information for city: Karaul
# Processing: 280 of 1000 - Three Hills
# Processing: 281 of 1000 - Solovetskiy
#    Unable to get weather information for city: Solovetskiy
# Processing: 282 of 1000 - Sipovo
# Processing: 283 of 1000 - Avera
# Processing: 284 of 1000 - Faya
# Processing: 285 of 1000 - Mezhdurechensk
# Processing: 286 of 1000 - Krasnoselkup
#    Unable to get weather information for city: Krasnoselkup
# Processing: 287 of 1000 - Kirakira
# Processing: 288 of 1000 - Mehran
# Processing: 289 of 1000 - Makakilo City
# Processing: 290 of 1000 - Qui Nhon
#    Unable to get weather information for city: Qui Nhon
# Processing: 291 of 1000 - Simbahan
# Processing: 292 of 1000 - Muros
# Processing: 293 of 1000 - Fortuna
# Processing: 294 of 1000 - Anuradhapura
# Processing: 295 of 1000 - Leones
# Processing: 296 of 1000 - Leshukonskoye
# Processing: 297 of 1000 - Umm Ruwabah
#    Unable to get weather information for city: Umm Ruwabah
# Processing: 298 of 1000 - Ginda
# Processing: 299 of 1000 - Mayna
# Processing: 300 of 1000 - Richards Bay
# Processing: 301 of 1000 - Sioux Lookout
# Processing: 302 of 1000 - Luau
# Processing: 303 of 1000 - Tilichiki
# Processing: 304 of 1000 - Vardo
# Processing: 305 of 1000 - Zilair
# Processing: 306 of 1000 - Yellowknife
# Processing: 307 of 1000 - Tupaciguara
# Processing: 308 of 1000 - Bolama
# Processing: 309 of 1000 - Lodwar
# Processing: 310 of 1000 - Boyolangu
# Processing: 311 of 1000 - Srednekolymsk
# Processing: 312 of 1000 - Flinders
# Processing: 313 of 1000 - Mahanoro
# Processing: 314 of 1000 - Byron Bay
# Processing: 315 of 1000 - Namibe
# Processing: 316 of 1000 - Comodoro Rivadavia
# Processing: 317 of 1000 - Cayenne
# Processing: 318 of 1000 - Ilulissat
# Processing: 319 of 1000 - Jahrom
#    Unable to get weather information for city: Jahrom
# Processing: 320 of 1000 - Chandausi
# Processing: 321 of 1000 - Kamenskoye
#    Unable to get weather information for city: Kamenskoye
# Processing: 322 of 1000 - Kalmunai
# Processing: 323 of 1000 - Olafsvik
#    Unable to get weather information for city: Olafsvik
# Processing: 324 of 1000 - Souris
# Processing: 325 of 1000 - Sitka
# Processing: 326 of 1000 - Estrela
# Processing: 327 of 1000 - Dapaong
# Processing: 328 of 1000 - Bilma
# Processing: 329 of 1000 - Roald
# Processing: 330 of 1000 - Chapais
# Processing: 331 of 1000 - Shevchenkove
# Processing: 332 of 1000 - Sao Joao Da Barra
# Processing: 333 of 1000 - Sechura
# Processing: 334 of 1000 - Nhulunbuy
# Processing: 335 of 1000 - Bayir
# Processing: 336 of 1000 - Isangel
# Processing: 337 of 1000 - Lorengau
# Processing: 338 of 1000 - Itamaraju
# Processing: 339 of 1000 - Aykhal
# Processing: 340 of 1000 - Batemans Bay
# Processing: 341 of 1000 - Awbari
# Processing: 342 of 1000 - Dedougou
# Processing: 343 of 1000 - Shingu
# Processing: 344 of 1000 - Port Augusta
# Processing: 345 of 1000 - Kara
#    Unable to get weather information for city: Kara
# Processing: 346 of 1000 - Necochea
# Processing: 347 of 1000 - Carnarvon
# Processing: 348 of 1000 - Bodden Town
# Processing: 349 of 1000 - Eldikan
#    Unable to get weather information for city: Eldikan
# Processing: 350 of 1000 - Oranjemund
# Processing: 351 of 1000 - Bellevue
# Processing: 352 of 1000 - Mikhaylov
# Processing: 353 of 1000 - Sfantu Gheorghe
# Processing: 354 of 1000 - Pangody
# Processing: 355 of 1000 - Kenai
# Processing: 356 of 1000 - Agva
#    Unable to get weather information for city: Agva
# Processing: 357 of 1000 - Urumqi
#    Unable to get weather information for city: Urumqi
# Processing: 358 of 1000 - Osmena
# Processing: 359 of 1000 - Karratha
# Processing: 360 of 1000 - Khash
# Processing: 361 of 1000 - Najran
# Processing: 362 of 1000 - Polunochnoye
# Processing: 363 of 1000 - Lavrentiya
# Processing: 364 of 1000 - Port Hedland
# Processing: 365 of 1000 - Manado
# Processing: 366 of 1000 - San Carlos De Bariloche
# Processing: 367 of 1000 - Grindavik
# Processing: 368 of 1000 - Ahipara
# Processing: 369 of 1000 - Mamaku
# Processing: 370 of 1000 - Pyaozerskiy
# Processing: 371 of 1000 - Melchor De Mencos
# Processing: 372 of 1000 - Kitakata
# Processing: 373 of 1000 - Savannah Bight
# Processing: 374 of 1000 - Anadyr
# Processing: 375 of 1000 - Busembatia
# Processing: 376 of 1000 - Petropavlovsk-Kamchatskiy
# Processing: 377 of 1000 - Bull Savanna
# Processing: 378 of 1000 - Hokitika
# Processing: 379 of 1000 - Diamantino
# Processing: 380 of 1000 - Taboga
# Processing: 381 of 1000 - Yomitan
#    Unable to get weather information for city: Yomitan
# Processing: 382 of 1000 - Sambava
# Processing: 383 of 1000 - Alofi
# Processing: 384 of 1000 - Wahran
#    Unable to get weather information for city: Wahran
# Processing: 385 of 1000 - Bontang
# Processing: 386 of 1000 - Nuuk
# Processing: 387 of 1000 - Bam
# Processing: 388 of 1000 - Abashiri
# Processing: 389 of 1000 - Lavumisa
# Processing: 390 of 1000 - Pimenta Bueno
# Processing: 391 of 1000 - Agadez
# Processing: 392 of 1000 - Stoyba
#    Unable to get weather information for city: Stoyba
# Processing: 393 of 1000 - Evensk
# Processing: 394 of 1000 - Nizhniy Kuranakh
# Processing: 395 of 1000 - San Policarpo
# Processing: 396 of 1000 - Mahibadhoo
# Processing: 397 of 1000 - Bansi
# Processing: 398 of 1000 - Bow Island
# Processing: 399 of 1000 - Batticaloa
# Processing: 400 of 1000 - Tommot
# Processing: 401 of 1000 - Nogliki
# Processing: 402 of 1000 - Margate
# Processing: 403 of 1000 - Rundu
# Processing: 404 of 1000 - Oranjestad
# Processing: 405 of 1000 - Bima
# Processing: 406 of 1000 - Marzuq
# Processing: 407 of 1000 - Krasnoarmeyskoye
# Processing: 408 of 1000 - Hvammstangi
#    Unable to get weather information for city: Hvammstangi
# Processing: 409 of 1000 - Ukiah
# Processing: 410 of 1000 - Aksu
# Processing: 411 of 1000 - Tukrah
#    Unable to get weather information for city: Tukrah
# Processing: 412 of 1000 - Chahal
# Processing: 413 of 1000 - Vila Franca Do Campo
# Processing: 414 of 1000 - Ostrovnoy
# Processing: 415 of 1000 - Orvieto
# Processing: 416 of 1000 - Nyurba
# Processing: 417 of 1000 - Kloulklubed
# Processing: 418 of 1000 - Hambantota
# Processing: 419 of 1000 - Alotau
#    Unable to get weather information for city: Alotau
# Processing: 420 of 1000 - Mahajanga
# Processing: 421 of 1000 - Chara
# Processing: 422 of 1000 - Cururupu
# Processing: 423 of 1000 - Presidente Dutra
# Processing: 424 of 1000 - Ulkan
# Processing: 425 of 1000 - Harindanga
# Processing: 426 of 1000 - Melfi
# Processing: 427 of 1000 - Aitape
# Processing: 428 of 1000 - Rocha
# Processing: 429 of 1000 - Grand River South East
#    Unable to get weather information for city: Grand River South East
# Processing: 430 of 1000 - Maragogi
# Processing: 431 of 1000 - Tecoanapa
# Processing: 432 of 1000 - San Rafael
# Processing: 433 of 1000 - Goderich
# Processing: 434 of 1000 - Grand-Lahou
# Processing: 435 of 1000 - Luganville
# Processing: 436 of 1000 - Shache
# Processing: 437 of 1000 - Hervey Bay
# Processing: 438 of 1000 - Port Macquarie
# Processing: 439 of 1000 - Husavik
# Processing: 440 of 1000 - Warah
# Processing: 441 of 1000 - Lexington
# Processing: 442 of 1000 - Olga
# Processing: 443 of 1000 - Zhigansk
# Processing: 444 of 1000 - Hailar
# Processing: 445 of 1000 - Bitung
# Processing: 446 of 1000 - Otradnoye
# Processing: 447 of 1000 - College
# Processing: 448 of 1000 - Ekhabi
# Processing: 449 of 1000 - Cidreira
# Processing: 450 of 1000 - Dingle
# Processing: 451 of 1000 - Xinqing
# Processing: 452 of 1000 - Ketchikan
# Processing: 453 of 1000 - Morant Bay
# Processing: 454 of 1000 - Sainte-Thecle
# Processing: 455 of 1000 - Brus Laguna
# Processing: 456 of 1000 - Khudumelapye
# Processing: 457 of 1000 - Soyo
# Processing: 458 of 1000 - Khorramshahr
# Processing: 459 of 1000 - Ouahigouya
# Processing: 460 of 1000 - Aldan
# Processing: 461 of 1000 - Tessalit
# Processing: 462 of 1000 - Beringovskiy
# Processing: 463 of 1000 - Samusu
#    Unable to get weather information for city: Samusu
# Processing: 464 of 1000 - Port Hardy
# Processing: 465 of 1000 - Tsentralnyy
#    Unable to get weather information for city: Tsentralnyy
# Processing: 466 of 1000 - Walvis Bay
# Processing: 467 of 1000 - Trincomalee
# Processing: 468 of 1000 - Treinta Y Tres
# Processing: 469 of 1000 - Tacuati
# Processing: 470 of 1000 - Athabasca
# Processing: 471 of 1000 - Palabuhanratu
#    Unable to get weather information for city: Palabuhanratu
# Processing: 472 of 1000 - Bengkulu
#    Unable to get weather information for city: Bengkulu
# Processing: 473 of 1000 - Waingapu
# Processing: 474 of 1000 - Panaba
# Processing: 475 of 1000 - Ibra
# Processing: 476 of 1000 - Trairi
# Processing: 477 of 1000 - Erzin
# Processing: 478 of 1000 - Cabrobo
# Processing: 479 of 1000 - Provideniya
# Processing: 480 of 1000 - Lanxi
# Processing: 481 of 1000 - Gidole
# Processing: 482 of 1000 - Toledo
# Processing: 483 of 1000 - Parrita
# Processing: 484 of 1000 - Boda
# Processing: 485 of 1000 - Sungairaya
# Processing: 486 of 1000 - Virginia Beach
# Processing: 487 of 1000 - Vysokogornyy
# Processing: 488 of 1000 - Solenzo
# Processing: 489 of 1000 - Sur
# Processing: 490 of 1000 - Mao
# Processing: 491 of 1000 - Ponot
# Processing: 492 of 1000 - Aberdeen
# Processing: 493 of 1000 - Ishigaki
# Processing: 494 of 1000 - Narsaq
# Processing: 495 of 1000 - Srandakan
# Processing: 496 of 1000 - Kutum
# Processing: 497 of 1000 - Abu Samrah
# Processing: 498 of 1000 - Bereda
# Processing: 499 of 1000 - Ubinskoye
# Processing: 500 of 1000 - Kavieng
# Processing: 501 of 1000 - Cazones
# Processing: 502 of 1000 - Pontarlier
# Processing: 503 of 1000 - Aswan
# Processing: 504 of 1000 - Almaznyy
# Processing: 505 of 1000 - Mandalgovi
# Processing: 506 of 1000 - Pondicherry
# Processing: 507 of 1000 - Balikpapan
# Processing: 508 of 1000 - Paamiut
# Processing: 509 of 1000 - Samarai
# Processing: 510 of 1000 - Loandjili
# Processing: 511 of 1000 - Komsomolskiy
# Processing: 512 of 1000 - Jakar
# Processing: 513 of 1000 - Dalby
# Processing: 514 of 1000 - Ovalle
# Processing: 515 of 1000 - Holly Hill
# Processing: 516 of 1000 - North Bend
# Processing: 517 of 1000 - Baiyin
# Processing: 518 of 1000 - Zephyrhills
# Processing: 519 of 1000 - Mormugao
#    Unable to get weather information for city: Mormugao
# Processing: 520 of 1000 - Dovers
# Processing: 521 of 1000 - Davidson
# Processing: 522 of 1000 - Inongo
# Processing: 523 of 1000 - Mitsamiouli
# Processing: 524 of 1000 - Prenzlau
# Processing: 525 of 1000 - San Andres
# Processing: 526 of 1000 - Shushtar
# Processing: 527 of 1000 - Barcelos
# Processing: 528 of 1000 - Visby
# Processing: 529 of 1000 - Tongzi
# Processing: 530 of 1000 - Esqueda
# Processing: 531 of 1000 - Torres
# Processing: 532 of 1000 - Araucaria
# Processing: 533 of 1000 - Temerloh
# Processing: 534 of 1000 - Ceuta
# Processing: 535 of 1000 - Peruibe
# Processing: 536 of 1000 - Makung
#    Unable to get weather information for city: Makung
# Processing: 537 of 1000 - Narrabri
# Processing: 538 of 1000 - Gonbad-E Qabus
# Processing: 539 of 1000 - Rio Gallegos
# Processing: 540 of 1000 - Kandrian
# Processing: 541 of 1000 - Coromandel
# Processing: 542 of 1000 - Barabai
# Processing: 543 of 1000 - Fatehpur
# Processing: 544 of 1000 - Shellbrook
# Processing: 545 of 1000 - Sooke
# Processing: 546 of 1000 - Djenne
# Processing: 547 of 1000 - Buraydah
# Processing: 548 of 1000 - Suarez
# Processing: 549 of 1000 - Praia Da Vitoria
# Processing: 550 of 1000 - Sayanogorsk
# Processing: 551 of 1000 - Emerald
# Processing: 552 of 1000 - Makokou
# Processing: 553 of 1000 - Kambia
# Processing: 554 of 1000 - Pustoshka
# Processing: 555 of 1000 - Gunjur
# Processing: 556 of 1000 - Namatanai
# Processing: 557 of 1000 - Hammerfest
# Processing: 558 of 1000 - Tsybli
# Processing: 559 of 1000 - Vestmanna
# Processing: 560 of 1000 - Onega
# Processing: 561 of 1000 - Coronado
# Processing: 562 of 1000 - Linfen
# Processing: 563 of 1000 - Beloha
# Processing: 564 of 1000 - Inhambane
# Processing: 565 of 1000 - Thaton
# Processing: 566 of 1000 - Zyryanka
# Processing: 567 of 1000 - Peniche
# Processing: 568 of 1000 - Bandar-E Anzali
# Processing: 569 of 1000 - Saint-Georges
# Processing: 570 of 1000 - Mapimi
# Processing: 571 of 1000 - Ulladulla
# Processing: 572 of 1000 - Te Anau
# Processing: 573 of 1000 - Taoudenni
# Processing: 574 of 1000 - Mukhen
# Processing: 575 of 1000 - Tarudant
#    Unable to get weather information for city: Tarudant
# Processing: 576 of 1000 - Kiunga
# Processing: 577 of 1000 - Marmaris
# Processing: 578 of 1000 - Danane
# Processing: 579 of 1000 - Martaban
# Processing: 580 of 1000 - Toliary
#    Unable to get weather information for city: Toliary
# Processing: 581 of 1000 - Dubti
# Processing: 582 of 1000 - Catuday
# Processing: 583 of 1000 - Oktyabrskoye
# Processing: 584 of 1000 - Khani
# Processing: 585 of 1000 - Kimbe
# Processing: 586 of 1000 - Macheng
# Processing: 587 of 1000 - The Valley
# Processing: 588 of 1000 - Khandyga
# Processing: 589 of 1000 - Vyazemskiy
# Processing: 590 of 1000 - Petrovsk
# Processing: 591 of 1000 - Koraput
# Processing: 592 of 1000 - Acarau
#    Unable to get weather information for city: Acarau
# Processing: 593 of 1000 - Mehamn
# Processing: 594 of 1000 - Imeni Zhelyabova
# Processing: 595 of 1000 - Sault Sainte Marie
# Processing: 596 of 1000 - College Station
# Processing: 597 of 1000 - Souillac
# Processing: 598 of 1000 - Murdochville
# Processing: 599 of 1000 - Graham
# Processing: 600 of 1000 - Hofn
# Processing: 601 of 1000 - Puerto Colombia
# Processing: 602 of 1000 - Mindelo
# Processing: 603 of 1000 - Rafraf
# Processing: 604 of 1000 - Jati
# Processing: 605 of 1000 - Eydhafushi
# Processing: 606 of 1000 - Bathsheba
# Processing: 607 of 1000 - Bela Vista
# Processing: 608 of 1000 - Ambon
# Processing: 609 of 1000 - Penzance
# Processing: 610 of 1000 - Lima
# Processing: 611 of 1000 - Suleja
# Processing: 612 of 1000 - Pedasi
# Processing: 613 of 1000 - Wittingen
# Processing: 614 of 1000 - Dalnegorsk
# Processing: 615 of 1000 - Itaituba
# Processing: 616 of 1000 - Kralendijk
# Processing: 617 of 1000 - Volginskiy
#    Unable to get weather information for city: Volginskiy
# Processing: 618 of 1000 - Moron
# Processing: 619 of 1000 - Esso
# Processing: 620 of 1000 - Qaqortoq
# Processing: 621 of 1000 - Salta
# Processing: 622 of 1000 - Bac Lieu
#    Unable to get weather information for city: Bac Lieu
# Processing: 623 of 1000 - Buchanan
# Processing: 624 of 1000 - Coulihaut
#    Unable to get weather information for city: Coulihaut
# Processing: 625 of 1000 - Fairbanks
# Processing: 626 of 1000 - Bondoukou
# Processing: 627 of 1000 - Kurten
# Processing: 628 of 1000 - Bahia Blanca
# Processing: 629 of 1000 - Vallenar
# Processing: 630 of 1000 - Maraba
# Processing: 631 of 1000 - Zadar
# Processing: 632 of 1000 - Sao Felix Do Xingu
# Processing: 633 of 1000 - Kyzyl-Mazhalyk
# Processing: 634 of 1000 - Chunskiy
# Processing: 635 of 1000 - Bandarbeyla
# Processing: 636 of 1000 - Umm Bab
# Processing: 637 of 1000 - Auki
# Processing: 638 of 1000 - Berdigestyakh
# Processing: 639 of 1000 - Chipinge
# Processing: 640 of 1000 - Saint Anthony
# Processing: 641 of 1000 - Hobyo
# Processing: 642 of 1000 - Ayan
# Processing: 643 of 1000 - Nishihara
# Processing: 644 of 1000 - Mount Isa
# Processing: 645 of 1000 - Yarmouth
# Processing: 646 of 1000 - Mountain Home
# Processing: 647 of 1000 - Tidore
#    Unable to get weather information for city: Tidore
# Processing: 648 of 1000 - Tumannyy
#    Unable to get weather information for city: Tumannyy
# Processing: 649 of 1000 - Axim
# Processing: 650 of 1000 - Senekal
# Processing: 651 of 1000 - Fethiye
# Processing: 652 of 1000 - Ilam
# Processing: 653 of 1000 - Lucapa
# Processing: 654 of 1000 - Mae Hong Son
# Processing: 655 of 1000 - Alta Floresta
# Processing: 656 of 1000 - Bolhrad
# Processing: 657 of 1000 - Portland
# Processing: 658 of 1000 - Taizhou
# Processing: 659 of 1000 - Eureka
# Processing: 660 of 1000 - Madiun
# Processing: 661 of 1000 - Masterton
# Processing: 662 of 1000 - Tawzar
#    Unable to get weather information for city: Tawzar
# Processing: 663 of 1000 - Punta Alta
# Processing: 664 of 1000 - Wahiawa
# Processing: 665 of 1000 - Rongcheng
# Processing: 666 of 1000 - Bela Vista Do Paraiso
# Processing: 667 of 1000 - Tanout
# Processing: 668 of 1000 - Pringsewu
# Processing: 669 of 1000 - Tupik
# Processing: 670 of 1000 - Rtishchevo
# Processing: 671 of 1000 - Limon
# Processing: 672 of 1000 - Anzio
# Processing: 673 of 1000 - Palasa
#    Unable to get weather information for city: Palasa
# Processing: 674 of 1000 - Luba
# Processing: 675 of 1000 - Linqing
# Processing: 676 of 1000 - Tucuman
# Processing: 677 of 1000 - Sakakah
#    Unable to get weather information for city: Sakakah
# Processing: 678 of 1000 - Manta
# Processing: 679 of 1000 - Dwarka
# Processing: 680 of 1000 - Pervomayskoye
# Processing: 681 of 1000 - Dudinka
# Processing: 682 of 1000 - Montceau-Les-Mines
# Processing: 683 of 1000 - Ternate
# Processing: 684 of 1000 - Ambanja
# Processing: 685 of 1000 - Novoagansk
# Processing: 686 of 1000 - Genhe
# Processing: 687 of 1000 - Whitley Bay
# Processing: 688 of 1000 - Popondetta
# Processing: 689 of 1000 - Haimen
# Processing: 690 of 1000 - Sohag
# Processing: 691 of 1000 - Malatya
#    Unable to get weather information for city: Malatya
# Processing: 692 of 1000 - Havre-Saint-Pierre
# Processing: 693 of 1000 - Taltal
# Processing: 694 of 1000 - Charagua
# Processing: 695 of 1000 - Nogent-Le-Rotrou
# Processing: 696 of 1000 - Fallon
# Processing: 697 of 1000 - Vestmannaeyjar
# Processing: 698 of 1000 - Chegdomyn
# Processing: 699 of 1000 - Burica
#    Unable to get weather information for city: Burica
# Processing: 700 of 1000 - Dengfeng
# Processing: 701 of 1000 - Muzquiz
#    Unable to get weather information for city: Muzquiz
# Processing: 702 of 1000 - Carutapera
# Processing: 703 of 1000 - Henties Bay
# Processing: 704 of 1000 - Lagoa Da Prata
# Processing: 705 of 1000 - Sampit
# Processing: 706 of 1000 - Thinadhoo
# Processing: 707 of 1000 - Darab
# Processing: 708 of 1000 - Novyy Buh
# Processing: 709 of 1000 - Baragua
# Processing: 710 of 1000 - Inirida
# Processing: 711 of 1000 - Maykor
# Processing: 712 of 1000 - Livingston
# Processing: 713 of 1000 - Cabedelo
# Processing: 714 of 1000 - Pangnirtung
# Processing: 715 of 1000 - Asau
#    Unable to get weather information for city: Asau
# Processing: 716 of 1000 - Urussu
# Processing: 717 of 1000 - Bur Gabo
#    Unable to get weather information for city: Bur Gabo
# Processing: 718 of 1000 - Mangrol
# Processing: 719 of 1000 - Kazalinsk
#    Unable to get weather information for city: Kazalinsk
# Processing: 720 of 1000 - Doha
# Processing: 721 of 1000 - Sao Francisco
# Processing: 722 of 1000 - Lamu
# Processing: 723 of 1000 - Gravdal
# Processing: 724 of 1000 - Capao Da Canoa
# Processing: 725 of 1000 - Haines Junction
# Processing: 726 of 1000 - Progreso
# Processing: 727 of 1000 - Merauke
# Processing: 728 of 1000 - Callaway
# Processing: 729 of 1000 - Khasan
# Processing: 730 of 1000 - Kupang
# Processing: 731 of 1000 - Havre
# Processing: 732 of 1000 - Aguimes
# Processing: 733 of 1000 - Arys
# Processing: 734 of 1000 - Amberley
# Processing: 735 of 1000 - Limache
# Processing: 736 of 1000 - Tomatlan
# Processing: 737 of 1000 - Esperanza
# Processing: 738 of 1000 - Aras
# Processing: 739 of 1000 - Nizwa
# Processing: 740 of 1000 - Palmer
# Processing: 741 of 1000 - Charters Towers
# Processing: 742 of 1000 - Umm Lajj
# Processing: 743 of 1000 - Pemagatsel
# Processing: 744 of 1000 - Do Rud
#    Unable to get weather information for city: Do Rud
# Processing: 745 of 1000 - Litoral Del San Juan
#    Unable to get weather information for city: Litoral Del San Juan
# Processing: 746 of 1000 - Hohhot
# Processing: 747 of 1000 - Calvinia
# Processing: 748 of 1000 - Martapura
# Processing: 749 of 1000 - Ambodifototra
#    Unable to get weather information for city: Ambodifototra
# Processing: 750 of 1000 - Show Low
# Processing: 751 of 1000 - Tigil
# Processing: 752 of 1000 - Manutuke
# Processing: 753 of 1000 - Mount Pleasant
# Processing: 754 of 1000 - Port-Cartier
# Processing: 755 of 1000 - Talpa
# Processing: 756 of 1000 - Casablanca
# Processing: 757 of 1000 - Vyartsilya
# Processing: 758 of 1000 - Ust-Kulom
# Processing: 759 of 1000 - Nioro
# Processing: 760 of 1000 - Linjiang
# Processing: 761 of 1000 - Farafangana
# Processing: 762 of 1000 - Soe
# Processing: 763 of 1000 - Bengkalis
#    Unable to get weather information for city: Bengkalis
# Processing: 764 of 1000 - Sal Rei
# Processing: 765 of 1000 - Itoman
# Processing: 766 of 1000 - Esna
# Processing: 767 of 1000 - Simplicio Mendes
# Processing: 768 of 1000 - Zavetnoye
# Processing: 769 of 1000 - Caraballeda
# Processing: 770 of 1000 - Orangeville
# Processing: 771 of 1000 - San Felipe
# Processing: 772 of 1000 - Batsfjord
# Processing: 773 of 1000 - Tazovskiy
# Processing: 774 of 1000 - Orjahovo
#    Unable to get weather information for city: Orjahovo
# Processing: 775 of 1000 - Thanatpin
# Processing: 776 of 1000 - Skrunda
# Processing: 777 of 1000 - Baykit
# Processing: 778 of 1000 - Karkaralinsk
#    Unable to get weather information for city: Karkaralinsk
# Processing: 779 of 1000 - Kiama
# Processing: 780 of 1000 - Dodge City
# Processing: 781 of 1000 - Matara
# Processing: 782 of 1000 - Gigmoto
# Processing: 783 of 1000 - Kulhudhuffushi
# Processing: 784 of 1000 - Puebloviejo
# Processing: 785 of 1000 - Huarmey
# Processing: 786 of 1000 - Nago
# Processing: 787 of 1000 - Vestbygda
#    Unable to get weather information for city: Vestbygda
# Processing: 788 of 1000 - Brigantine
# Processing: 789 of 1000 - Zeya
# Processing: 790 of 1000 - Valparaiso
# Processing: 791 of 1000 - Florianopolis
# Processing: 792 of 1000 - Zhanatas
#    Unable to get weather information for city: Zhanatas
# Processing: 793 of 1000 - Muroto
# Processing: 794 of 1000 - Abeche
# Processing: 795 of 1000 - Hun
# Processing: 796 of 1000 - Mutsamudu
#    Unable to get weather information for city: Mutsamudu
# Processing: 797 of 1000 - Ondangwa
# Processing: 798 of 1000 - Daru
# Processing: 799 of 1000 - Rungata
#    Unable to get weather information for city: Rungata
# Processing: 800 of 1000 - Aliquippa
# Processing: 801 of 1000 - Shenjiamen
# Processing: 802 of 1000 - Azad Shahr
#    Unable to get weather information for city: Azad Shahr
# Processing: 803 of 1000 - Megion
# Processing: 804 of 1000 - Lingao
# Processing: 805 of 1000 - Eirunepe
# Processing: 806 of 1000 - Sarishabari
# Processing: 807 of 1000 - Orativ
# Processing: 808 of 1000 - Carepa
# Processing: 809 of 1000 - Manggar
# Processing: 810 of 1000 - Jalu
# Processing: 811 of 1000 - Kankaanpaa
# Processing: 812 of 1000 - Chagda
#    Unable to get weather information for city: Chagda
# Processing: 813 of 1000 - Padang
# Processing: 814 of 1000 - Bria
# Processing: 815 of 1000 - Galchino
#    Unable to get weather information for city: Galchino
# Processing: 816 of 1000 - Londoko
#    Unable to get weather information for city: Londoko
# Processing: 817 of 1000 - Tucupita
# Processing: 818 of 1000 - Enid
# Processing: 819 of 1000 - Kargil
# Processing: 820 of 1000 - Tabuk
# Processing: 821 of 1000 - Patea
# Processing: 822 of 1000 - Tingi
# Processing: 823 of 1000 - Yeppoon
# Processing: 824 of 1000 - Aksarka
# Processing: 825 of 1000 - Otofuke
# Processing: 826 of 1000 - Arkhara
# Processing: 827 of 1000 - Eyl
# Processing: 828 of 1000 - Alugan
# Processing: 829 of 1000 - Norman
# Processing: 830 of 1000 - Kitgum
# Processing: 831 of 1000 - Yumen
# Processing: 832 of 1000 - Talara
# Processing: 833 of 1000 - Tabiauea
#    Unable to get weather information for city: Tabiauea
# Processing: 834 of 1000 - Chumikan
# Processing: 835 of 1000 - Manzhouli
# Processing: 836 of 1000 - Riyadh
# Processing: 837 of 1000 - Santa Marta
# Processing: 838 of 1000 - Nabire
# Processing: 839 of 1000 - Fort-Shevchenko
# Processing: 840 of 1000 - Korla
#    Unable to get weather information for city: Korla
# Processing: 841 of 1000 - Chaochou
#    Unable to get weather information for city: Chaochou
# Processing: 842 of 1000 - Wajid
# Processing: 843 of 1000 - Bud
# Processing: 844 of 1000 - Barranca
# Processing: 845 of 1000 - Canutama
# Processing: 846 of 1000 - Sao Joao Evangelista
# Processing: 847 of 1000 - Konstantinovskiy
# Processing: 848 of 1000 - Grand Gaube
# Processing: 849 of 1000 - Filadelfia
# Processing: 850 of 1000 - Ronchin
# Processing: 851 of 1000 - Kieta
# Processing: 852 of 1000 - Tlahualilo
#    Unable to get weather information for city: Tlahualilo
# Processing: 853 of 1000 - Mandiana
# Processing: 854 of 1000 - La Palma
# Processing: 855 of 1000 - Cheuskiny
#    Unable to get weather information for city: Cheuskiny
# Processing: 856 of 1000 - Steamboat Springs
# Processing: 857 of 1000 - Pokhvistnevo
# Processing: 858 of 1000 - General Roca
# Processing: 859 of 1000 - Zhoucheng
# Processing: 860 of 1000 - Lumberton
# Processing: 861 of 1000 - Qarchi Gak
# Processing: 862 of 1000 - Gangotri
#    Unable to get weather information for city: Gangotri
# Processing: 863 of 1000 - San Joaquin
# Processing: 864 of 1000 - Moba
# Processing: 865 of 1000 - Colares
# Processing: 866 of 1000 - Andijon
# Processing: 867 of 1000 - Iguatu
# Processing: 868 of 1000 - Laguna
# Processing: 869 of 1000 - Chadiza
# Processing: 870 of 1000 - Vila
# Processing: 871 of 1000 - Bay Roberts
# Processing: 872 of 1000 - Kismayo
#    Unable to get weather information for city: Kismayo
# Processing: 873 of 1000 - Juba
# Processing: 874 of 1000 - Orcopampa
# Processing: 875 of 1000 - Galeana
# Processing: 876 of 1000 - San Felix
# Processing: 877 of 1000 - Shimsk
# Processing: 878 of 1000 - Meyungs
#    Unable to get weather information for city: Meyungs
# Processing: 879 of 1000 - Chastyye
# Processing: 880 of 1000 - Asfi
#    Unable to get weather information for city: Asfi
# Processing: 881 of 1000 - Devils Lake
# Processing: 882 of 1000 - Pitea
# Processing: 883 of 1000 - Ranong
# Processing: 884 of 1000 - Karpathos
# Processing: 885 of 1000 - San-Pedro
# Processing: 886 of 1000 - Xiongzhou
# Processing: 887 of 1000 - Marienburg
# Processing: 888 of 1000 - Vredendal
# Processing: 889 of 1000 - Santa Barbara
# Processing: 890 of 1000 - Tias
# Processing: 891 of 1000 - Jieshi
# Processing: 892 of 1000 - Fort Frances
# Processing: 893 of 1000 - Muisne
# Processing: 894 of 1000 - Saint-Louis
# Processing: 895 of 1000 - Mahadday Weyne
#    Unable to get weather information for city: Mahadday Weyne
# Processing: 896 of 1000 - Yatou
# Processing: 897 of 1000 - Semey
# Processing: 898 of 1000 - Alekseyevka
# Processing: 899 of 1000 - Nacimiento
# Processing: 900 of 1000 - Paradwip
#    Unable to get weather information for city: Paradwip
# Processing: 901 of 1000 - Zelenogorsk
# Processing: 902 of 1000 - Batagay-Alyta
# Processing: 903 of 1000 - Flin Flon
# Processing: 904 of 1000 - Russell
# Processing: 905 of 1000 - Sortavala
# Processing: 906 of 1000 - Chimbote
# Processing: 907 of 1000 - Nouadhibou
# Processing: 908 of 1000 - Dzilam Gonzalez
# Processing: 909 of 1000 - Labytnangi
# Processing: 910 of 1000 - Puerto Del Rosario
# Processing: 911 of 1000 - Poplar Bluff
# Processing: 912 of 1000 - Santander
# Processing: 913 of 1000 - Witu
# Processing: 914 of 1000 - Babanka
# Processing: 915 of 1000 - Dilla
# Processing: 916 of 1000 - Stokmarknes
# Processing: 917 of 1000 - Tirlyanskiy
# Processing: 918 of 1000 - Fort Nelson
# Processing: 919 of 1000 - Pingyin
# Processing: 920 of 1000 - Matameye
#    Unable to get weather information for city: Matameye
# Processing: 921 of 1000 - Constitucion
# Processing: 922 of 1000 - Natal
# Processing: 923 of 1000 - Pucara
# Processing: 924 of 1000 - Iberia
# Processing: 925 of 1000 - Kudahuvadhoo
# Processing: 926 of 1000 - Kibala
# Processing: 927 of 1000 - Ashland
# Processing: 928 of 1000 - Shush
# Processing: 929 of 1000 - Marsh Harbour
# Processing: 930 of 1000 - Moyale
# Processing: 931 of 1000 - Uyemskiy
# Processing: 932 of 1000 - Puerto Baquerizo Moreno
# Processing: 933 of 1000 - Shkotovo-22
#    Unable to get weather information for city: Shkotovo-22
# Processing: 934 of 1000 - Sinnai
# Processing: 935 of 1000 - Socorro
# Processing: 936 of 1000 - Turbat
# Processing: 937 of 1000 - Frankfort
# Processing: 938 of 1000 - Linxia
# Processing: 939 of 1000 - Kantabanji
# Processing: 940 of 1000 - Newtonmore
# Processing: 941 of 1000 - Porgera
# Processing: 942 of 1000 - Quesnel
# Processing: 943 of 1000 - Sataua
#    Unable to get weather information for city: Sataua
# Processing: 944 of 1000 - Konya
# Processing: 945 of 1000 - Tevriz
# Processing: 946 of 1000 - Basiad
# Processing: 947 of 1000 - Petawawa
# Processing: 948 of 1000 - Tenenkou
# Processing: 949 of 1000 - Armacao Dos Buzios
#    Unable to get weather information for city: Armacao Dos Buzios
# Processing: 950 of 1000 - Manokwari
# Processing: 951 of 1000 - Severodvinsk
# Processing: 952 of 1000 - Teguldet
# Processing: 953 of 1000 - Akyab
#    Unable to get weather information for city: Akyab
# Processing: 954 of 1000 - Excelsior Springs
# Processing: 955 of 1000 - Paternion
# Processing: 956 of 1000 - Golden
# Processing: 957 of 1000 - Morro Bay
# Processing: 958 of 1000 - Tshikapa
# Processing: 959 of 1000 - Wenling
# Processing: 960 of 1000 - Colesberg
# Processing: 961 of 1000 - Beyneu
# Processing: 962 of 1000 - Gerash
# Processing: 963 of 1000 - Mawlaik
# Processing: 964 of 1000 - Hondo
# Processing: 965 of 1000 - Topeka
# Processing: 966 of 1000 - Pontiac
# Processing: 967 of 1000 - Sawakin
# Processing: 968 of 1000 - Almenara
# Processing: 969 of 1000 - Isnos
# Processing: 970 of 1000 - Waterloo
# Processing: 971 of 1000 - Radstadt
# Processing: 972 of 1000 - Blackwater
# Processing: 973 of 1000 - Providencia
# Processing: 974 of 1000 - Hope
# Processing: 975 of 1000 - Weinan
# Processing: 976 of 1000 - Sleaford
# Processing: 977 of 1000 - Bokspits
#    Unable to get weather information for city: Bokspits
# Processing: 978 of 1000 - La Ronge
# Processing: 979 of 1000 - Labuan
# Processing: 980 of 1000 - Basco
# Processing: 981 of 1000 - Yuli
# Processing: 982 of 1000 - Halalo
#    Unable to get weather information for city: Halalo
# Processing: 983 of 1000 - Zhangye
# Processing: 984 of 1000 - Abu Kamal
# Processing: 985 of 1000 - Seoul
# Processing: 986 of 1000 - Azimur
#    Unable to get weather information for city: Azimur
# Processing: 987 of 1000 - Orange
# Processing: 988 of 1000 - Aracoiaba
# Processing: 989 of 1000 - Ascension
#    Unable to get weather information for city: Ascension
# Processing: 990 of 1000 - Maicao
# Processing: 991 of 1000 - Imeni Poliny Osipenko
# Processing: 992 of 1000 - Tawkar
#    Unable to get weather information for city: Tawkar
# Processing: 993 of 1000 - Rio Grande
# Processing: 994 of 1000 - Killybegs
# Processing: 995 of 1000 - Araouane
# Processing: 996 of 1000 - Kaeo
# Processing: 997 of 1000 - Greystones
# Processing: 998 of 1000 - Belaya Gora
# Processing: 999 of 1000 - Pascagoula
# Processing: 1000 of 1000 - Jumla
#
# Completed getting data. Total Cities: 893  Error Cities: 107

# %%
#-- Prepare Data For Charting

#- Create Data Frame
weather_df = pd.DataFrame(weatherData)


#- Fix Humidity Values
#  Found at least one record that had invalid humidity % of 290
weather_df.loc[weather_df['Humidity'] > 100, 'Humidity'] = 100


#- Export to csv
exportDataPath = os.path.join(".", "Output", "WeatherData.cvs")

weather_df.to_csv(exportDataPath, encoding='utf-8', index=False)


#- Preview Dataframe
weather_df.head()
# Out:
#              City Country  Latitude  Longitude  Temperature  WindSpeed  \
# 0     Tuktoyaktuk      CA     69.44    -133.03        15.80      20.80
# 1  Saint-Francois      FR     46.42       3.91        53.60       9.17
# 2          Hobart      AU    -42.88     147.33        62.01       8.05
# 3          Albany      US     42.65     -73.75        39.00       3.40
# 4        Khatanga      RU     71.98     102.47        -0.10      18.39
#
#    Humidity  Cloudiness
# 0        78          90
# 1        54           0
# 2        71           0
# 3        40          90
# 4        75          44

# %%
#-- Create Date for Plots
dateInfo = datetime.datetime.now().strftime("%B %-d, %Y")

# %%
#-- Plot Latitude vs Temperature

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Temperature'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Max Temperature ({dateInfo})')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
temperatureImagePath = os.path.join(".", "Output", "LatitudeAndMaxTemperature.png")

plt.savefig(temperatureImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Humidity

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Humidity ({dateInfo})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
humidityImagePath = os.path.join(".", "Output", "LatitudeAndHumidity.png")

plt.savefig(humidityImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Cloudiness

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Cloudiness ({dateInfo})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
cloudinessImagePath = os.path.join(".", "Output", "LatitudeAndCloudiness.png")

plt.savefig(cloudinessImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Wind Speed

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['WindSpeed'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Wind Speed ({dateInfo})')
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
windImagePath = os.path.join(".", "Output", "LatitudeAndWindSpeed.png")

plt.savefig(windImagePath)


#- Show Chart
plt.show()
