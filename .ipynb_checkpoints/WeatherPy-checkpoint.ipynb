# %% [markdown]
# ## WeatherPy: Visualizing weather based on Latitude
# March 2, 2019
# Scott McEachern

# %%
#-- Import Libraries
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import requests
import datetime

# OpenWeatherMap API Key located in secrets.py; .gitignore prevents secrets.py from push to GitHub
from secrets import api_key

# citipy library to lookup city name based on lat/long; 
# require installation of dependencies with: pip install citipy
from citipy import citipy

# %%
#-- Generate List of Cities

# Number of random locations to calculate
numRandomLocations = 4000

# Total number of cities to get weather information from API
numCities = 1000


#- Create Random Coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=numRandomLocations)
lngs = np.random.uniform(low=-180.000, high=180.000, size=numRandomLocations)


#- Merge into Zip
lat_lngs = zip(lats, lngs)


#- Find City Name
cityNames = []

for lat_lng in lat_lngs:
    
    # Get nearest city
    cityName = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # Determine new city name
    if (cityName not in cityNames):
        cityNames.append(cityName)

        # Check if reached number of cities used with analysis
        if (len(cityNames) == numCities):
            break

            
#- Information on cities
print(f'Created list of city names; total {len(cityNames)}')
# Out:
# Created list of city names; total 1000

# %%
def getWeatherForCity(cityName):
    ''' Queries the OpenWeatherData API to get the current weather conditions for the city name provided.
    Exceptions are captured and when exception, metadata printed to console.
    
    Accepts : cityName (str) Name of the city to search to get current weather information for
    
    Returns : List - contains metadata from the API; returns None when exception or not 200 response
                0 - (str) City Name
                1 - (str) Country Code
                2 - (num) Latitude
                3 - (num) Longitude
                4 - (num) Max Temperature - F
                5 - (num) Windspeed - MPH
                6 - (num) Humidity - %
                7 - (num) Cloudiness - %
    '''
    
    try:
        
        #- Prepare URL
        baseWeatherUrl = "http://api.openweathermap.org/data/2.5/weather"
        unitFormat = "imperial"
        
        queryUrl = f"{baseWeatherUrl}?q={cityName}&units={unitFormat}&appid={api_key}"
        
        
        #- Get Weather from API
        response = requests.get(queryUrl)
        
        
        #- Check Response
        cityWeather = []
        
        if (response.status_code == requests.codes.ok):
            
            # Get Json from Response
            responseJson = response.json()
            
            
            # Get Weather Information
            cityWeather.append(responseJson['name'])
            cityWeather.append(responseJson['sys']['country'])
            
            cityWeather.append(responseJson['coord']['lat'])
            cityWeather.append(responseJson['coord']['lon'])
            
            cityWeather.append(responseJson['main']['temp_max'])
            cityWeather.append(responseJson['wind']['speed'])
                        
            cityWeather.append(responseJson['main']['humidity'])
            cityWeather.append(responseJson['clouds']['all'])
        
        else:
            #- Response not valid; return None
            return
        
        
        return cityWeather
        
    except Exception as e:
        print(f"   Exception getting weather from API. City: {cityName} Error Type: {type(e)} Info: {e}")

# %%
##- Get Weather for City

#- Prepare Dictionary to store results
weatherData = {
    'City': [],
    'Country': [],
    'Latitude' : [],
    'Longitude' : [],
    'Temperature' : [],
    'WindSpeed' : [],
    'Humidity' : [],
    'Cloudiness': [],
    }


#- Display Message
print("> Start data retrieval")


#- Get Weather Information
errorCounter = 0
counter = 0

for cityName in cityNames:
    
    # Progress Message
    counter += 1
    
    print(f"Processing: {counter} of {len(cityNames)} - {cityName.title()}")
    
    
    # Get Weather for City
    cityInfo = getWeatherForCity(cityName)
    
    
    # Check Results from API
    if (cityInfo != None):
        weatherData['City'].append(cityInfo[0])
        weatherData['Country'].append(cityInfo[1])
        weatherData['Latitude'].append(cityInfo[2])
        weatherData['Longitude'].append(cityInfo[3])
        weatherData['Temperature'].append(cityInfo[4])
        weatherData['WindSpeed'].append(cityInfo[5])
        weatherData['Humidity'].append(cityInfo[6])
        weatherData['Cloudiness'].append(cityInfo[7])
        
    else:
        print(f"   Unable to get weather information for city: {cityName.title()}")
        errorCounter +=1
    
    
#- Display Message
print(" ")
print(f"Completed getting data. Total Cities: {len(weatherData['City'])}  Error Cities: {errorCounter}")
# Out:
# > Start data retrieval
# Processing: 1 of 1000 - Asau
#    Unable to get weather information for city: Asau
# Processing: 2 of 1000 - Kapaa
# Processing: 3 of 1000 - Busselton
# Processing: 4 of 1000 - Tabas
# Processing: 5 of 1000 - Teeli
# Processing: 6 of 1000 - Vaitape
# Processing: 7 of 1000 - Flin Flon
# Processing: 8 of 1000 - Illoqqortoormiut
#    Unable to get weather information for city: Illoqqortoormiut
# Processing: 9 of 1000 - Hobart
# Processing: 10 of 1000 - Ushuaia
# Processing: 11 of 1000 - Avarua
# Processing: 12 of 1000 - Puerto Ayora
# Processing: 13 of 1000 - Otavalo
# Processing: 14 of 1000 - Labutta
#    Unable to get weather information for city: Labutta
# Processing: 15 of 1000 - Taltal
# Processing: 16 of 1000 - Arraial Do Cabo
# Processing: 17 of 1000 - Vila Velha
# Processing: 18 of 1000 - Saskylakh
# Processing: 19 of 1000 - Taolanaro
#    Unable to get weather information for city: Taolanaro
# Processing: 20 of 1000 - New Norfolk
# Processing: 21 of 1000 - East London
# Processing: 22 of 1000 - Nadvoitsy
# Processing: 23 of 1000 - Bredasdorp
# Processing: 24 of 1000 - Punta Arenas
# Processing: 25 of 1000 - Miyako
# Processing: 26 of 1000 - Tuktoyaktuk
# Processing: 27 of 1000 - Sitka
# Processing: 28 of 1000 - Albany
# Processing: 29 of 1000 - Atar
# Processing: 30 of 1000 - Mataura
# Processing: 31 of 1000 - Hithadhoo
# Processing: 32 of 1000 - Belushya Guba
#    Unable to get weather information for city: Belushya Guba
# Processing: 33 of 1000 - San Vicente
# Processing: 34 of 1000 - Port Elizabeth
# Processing: 35 of 1000 - Yining
# Processing: 36 of 1000 - Longyearbyen
# Processing: 37 of 1000 - Almeirim
# Processing: 38 of 1000 - Lavrentiya
# Processing: 39 of 1000 - Qaanaaq
# Processing: 40 of 1000 - Los Llanos De Aridane
# Processing: 41 of 1000 - Rikitea
# Processing: 42 of 1000 - Nikolayevsk-Na-Amure
# Processing: 43 of 1000 - Lorengau
# Processing: 44 of 1000 - Cidreira
# Processing: 45 of 1000 - Mundo Nuevo
# Processing: 46 of 1000 - Williston
# Processing: 47 of 1000 - Bluff
# Processing: 48 of 1000 - Ambilobe
# Processing: 49 of 1000 - Purranque
# Processing: 50 of 1000 - Castro
# Processing: 51 of 1000 - Carutapera
# Processing: 52 of 1000 - Port Alfred
# Processing: 53 of 1000 - Kaitangata
# Processing: 54 of 1000 - Srandakan
# Processing: 55 of 1000 - Ostrovnoy
# Processing: 56 of 1000 - Muroto
# Processing: 57 of 1000 - Billings
# Processing: 58 of 1000 - Strezhevoy
# Processing: 59 of 1000 - Felidhoo
#    Unable to get weather information for city: Felidhoo
# Processing: 60 of 1000 - Walvis Bay
# Processing: 61 of 1000 - Navrongo
# Processing: 62 of 1000 - Barrow
# Processing: 63 of 1000 - Kiruna
# Processing: 64 of 1000 - Carnarvon
# Processing: 65 of 1000 - Dikson
# Processing: 66 of 1000 - Hermanus
# Processing: 67 of 1000 - Saint-Philippe
# Processing: 68 of 1000 - Haines Junction
# Processing: 69 of 1000 - Katsuura
# Processing: 70 of 1000 - Manjeshwar
# Processing: 71 of 1000 - Alamos
# Processing: 72 of 1000 - Hilo
# Processing: 73 of 1000 - Shimoda
# Processing: 74 of 1000 - Cabedelo
# Processing: 75 of 1000 - Hasaki
# Processing: 76 of 1000 - Zastavna
# Processing: 77 of 1000 - Panacan
# Processing: 78 of 1000 - Amderma
#    Unable to get weather information for city: Amderma
# Processing: 79 of 1000 - Vaini
# Processing: 80 of 1000 - George
# Processing: 81 of 1000 - Aykhal
# Processing: 82 of 1000 - Mahebourg
# Processing: 83 of 1000 - Provideniya
# Processing: 84 of 1000 - Jamestown
# Processing: 85 of 1000 - Nizhneyansk
#    Unable to get weather information for city: Nizhneyansk
# Processing: 86 of 1000 - Kariba
# Processing: 87 of 1000 - Bethel
# Processing: 88 of 1000 - Nizhniy Kuranakh
# Processing: 89 of 1000 - Torbay
# Processing: 90 of 1000 - Port Hedland
# Processing: 91 of 1000 - Karratha
# Processing: 92 of 1000 - Oriximina
# Processing: 93 of 1000 - Ulcinj
# Processing: 94 of 1000 - Tikri
# Processing: 95 of 1000 - Izhma
# Processing: 96 of 1000 - Geraldton
# Processing: 97 of 1000 - Abha
# Processing: 98 of 1000 - Meyungs
#    Unable to get weather information for city: Meyungs
# Processing: 99 of 1000 - Rapina
# Processing: 100 of 1000 - Bayan
# Processing: 101 of 1000 - Praia
# Processing: 102 of 1000 - Lakes Entrance
# Processing: 103 of 1000 - Richards Bay
# Processing: 104 of 1000 - Barentsburg
#    Unable to get weather information for city: Barentsburg
# Processing: 105 of 1000 - Atuona
# Processing: 106 of 1000 - Manta
# Processing: 107 of 1000 - Kruisfontein
# Processing: 108 of 1000 - Athabasca
# Processing: 109 of 1000 - Staroaleyskoye
# Processing: 110 of 1000 - Grand River South East
#    Unable to get weather information for city: Grand River South East
# Processing: 111 of 1000 - Sisimiut
# Processing: 112 of 1000 - Cravo Norte
# Processing: 113 of 1000 - Tasiilaq
# Processing: 114 of 1000 - Byron Bay
# Processing: 115 of 1000 - Sotouboua
# Processing: 116 of 1000 - Grindavik
# Processing: 117 of 1000 - Guozhen
# Processing: 118 of 1000 - Upernavik
# Processing: 119 of 1000 - Cape Town
# Processing: 120 of 1000 - Balikpapan
# Processing: 121 of 1000 - Lahad Datu
# Processing: 122 of 1000 - Anito
# Processing: 123 of 1000 - Kyzyl-Suu
# Processing: 124 of 1000 - Mar Del Plata
# Processing: 125 of 1000 - Ballina
# Processing: 126 of 1000 - Hofn
# Processing: 127 of 1000 - Ponta Do Sol
# Processing: 128 of 1000 - Solnechnyy
# Processing: 129 of 1000 - Longhua
# Processing: 130 of 1000 - Mabaruma
# Processing: 131 of 1000 - Mount Gambier
# Processing: 132 of 1000 - San Patricio
# Processing: 133 of 1000 - Bodden Town
# Processing: 134 of 1000 - Kalang
# Processing: 135 of 1000 - Udachnyy
# Processing: 136 of 1000 - Port Hardy
# Processing: 137 of 1000 - Bambous Virieux
# Processing: 138 of 1000 - Kununurra
# Processing: 139 of 1000 - Bacolod
# Processing: 140 of 1000 - Ahtopol
# Processing: 141 of 1000 - Nikolskoye
# Processing: 142 of 1000 - Narsaq
# Processing: 143 of 1000 - Ribeira Grande
# Processing: 144 of 1000 - Manzanillo
# Processing: 145 of 1000 - Anori
# Processing: 146 of 1000 - Lagoa
# Processing: 147 of 1000 - Aklavik
# Processing: 148 of 1000 - Tumannyy
#    Unable to get weather information for city: Tumannyy
# Processing: 149 of 1000 - Tazmalt
# Processing: 150 of 1000 - Airai
# Processing: 151 of 1000 - Codrington
# Processing: 152 of 1000 - Cayenne
# Processing: 153 of 1000 - Panguipulli
# Processing: 154 of 1000 - Inhuma
# Processing: 155 of 1000 - Tsihombe
#    Unable to get weather information for city: Tsihombe
# Processing: 156 of 1000 - Edwardsville
# Processing: 157 of 1000 - Valparaiso
# Processing: 158 of 1000 - Butaritari
# Processing: 159 of 1000 - Wamba
# Processing: 160 of 1000 - Sungaipenuh
# Processing: 161 of 1000 - Buala
# Processing: 162 of 1000 - Tselinnoye
# Processing: 163 of 1000 - Sovetskiy
# Processing: 164 of 1000 - Tsabong
# Processing: 165 of 1000 - Viligili
#    Unable to get weather information for city: Viligili
# Processing: 166 of 1000 - Komsomolskiy
# Processing: 167 of 1000 - Trincomalee
# Processing: 168 of 1000 - Eskisehir
# Processing: 169 of 1000 - Tortoli
# Processing: 170 of 1000 - Jumla
# Processing: 171 of 1000 - Salalah
# Processing: 172 of 1000 - Caravelas
# Processing: 173 of 1000 - Chuy
# Processing: 174 of 1000 - Puerto Colombia
# Processing: 175 of 1000 - Biltine
# Processing: 176 of 1000 - Amga
# Processing: 177 of 1000 - Svarstad
# Processing: 178 of 1000 - Victoria
# Processing: 179 of 1000 - Vanimo
# Processing: 180 of 1000 - Rawson
# Processing: 181 of 1000 - Mishkino
# Processing: 182 of 1000 - Karpathos
# Processing: 183 of 1000 - Camacha
# Processing: 184 of 1000 - Yatou
# Processing: 185 of 1000 - Saint-Georges
# Processing: 186 of 1000 - Saleaula
#    Unable to get weather information for city: Saleaula
# Processing: 187 of 1000 - Lebu
# Processing: 188 of 1000 - Joao Pinheiro
# Processing: 189 of 1000 - Tiksi
# Processing: 190 of 1000 - Gastonia
# Processing: 191 of 1000 - Falam
# Processing: 192 of 1000 - Rio Grande
# Processing: 193 of 1000 - Matiri
# Processing: 194 of 1000 - Cabo San Lucas
# Processing: 195 of 1000 - Yangjiang
# Processing: 196 of 1000 - Bengkulu
#    Unable to get weather information for city: Bengkulu
# Processing: 197 of 1000 - Vostok
# Processing: 198 of 1000 - Jiroft
#    Unable to get weather information for city: Jiroft
# Processing: 199 of 1000 - Fougamou
# Processing: 200 of 1000 - Leinefelde
# Processing: 201 of 1000 - Severo-Kurilsk
# Processing: 202 of 1000 - Luganville
# Processing: 203 of 1000 - San Ignacio
# Processing: 204 of 1000 - Alice Springs
# Processing: 205 of 1000 - Limon
# Processing: 206 of 1000 - San Jose
# Processing: 207 of 1000 - Pula
# Processing: 208 of 1000 - Tornio
# Processing: 209 of 1000 - Kodiak
# Processing: 210 of 1000 - Husavik
# Processing: 211 of 1000 - Puerto Escondido
# Processing: 212 of 1000 - Warqla
#    Unable to get weather information for city: Warqla
# Processing: 213 of 1000 - Dicabisagan
# Processing: 214 of 1000 - Barabai
# Processing: 215 of 1000 - Roald
# Processing: 216 of 1000 - Rovaniemi
# Processing: 217 of 1000 - Aswan
# Processing: 218 of 1000 - Myrhorod
# Processing: 219 of 1000 - Northam
# Processing: 220 of 1000 - Khatanga
# Processing: 221 of 1000 - Nanortalik
# Processing: 222 of 1000 - Constitucion
# Processing: 223 of 1000 - Lyubim
# Processing: 224 of 1000 - Chalus
# Processing: 225 of 1000 - Vila Do Maio
# Processing: 226 of 1000 - Faanui
# Processing: 227 of 1000 - Dhidhdhoo
# Processing: 228 of 1000 - Ashland
# Processing: 229 of 1000 - Chapais
# Processing: 230 of 1000 - Saldanha
# Processing: 231 of 1000 - Pacific Grove
# Processing: 232 of 1000 - Sao Filipe
# Processing: 233 of 1000 - Teya
# Processing: 234 of 1000 - Lasa
# Processing: 235 of 1000 - Berlevag
# Processing: 236 of 1000 - Karasjok
# Processing: 237 of 1000 - Wageningen
# Processing: 238 of 1000 - Huntsville
# Processing: 239 of 1000 - Vung Tau
# Processing: 240 of 1000 - Palmer
# Processing: 241 of 1000 - Chudovo
# Processing: 242 of 1000 - Acapulco
# Processing: 243 of 1000 - Puerto Madryn
# Processing: 244 of 1000 - Mogocha
# Processing: 245 of 1000 - Nivala
# Processing: 246 of 1000 - Lompoc
# Processing: 247 of 1000 - Liberia
# Processing: 248 of 1000 - Pokhara
# Processing: 249 of 1000 - Tuatapere
# Processing: 250 of 1000 - Teneguiban
#    Unable to get weather information for city: Teneguiban
# Processing: 251 of 1000 - Waipawa
# Processing: 252 of 1000 - Fort Nelson
# Processing: 253 of 1000 - Yulara
# Processing: 254 of 1000 - Eirunepe
# Processing: 255 of 1000 - Canico
# Processing: 256 of 1000 - Kaeo
# Processing: 257 of 1000 - Evensk
# Processing: 258 of 1000 - Kavaratti
# Processing: 259 of 1000 - Lolua
#    Unable to get weather information for city: Lolua
# Processing: 260 of 1000 - Mutsamudu
#    Unable to get weather information for city: Mutsamudu
# Processing: 261 of 1000 - Rancho Palos Verdes
# Processing: 262 of 1000 - Zhezkazgan
# Processing: 263 of 1000 - Bathsheba
# Processing: 264 of 1000 - Nome
# Processing: 265 of 1000 - Pierre
# Processing: 266 of 1000 - Georgetown
# Processing: 267 of 1000 - Isangel
# Processing: 268 of 1000 - Talnakh
# Processing: 269 of 1000 - Thilogne
#    Unable to get weather information for city: Thilogne
# Processing: 270 of 1000 - Sterling
# Processing: 271 of 1000 - Harnosand
# Processing: 272 of 1000 - Okhotsk
# Processing: 273 of 1000 - Skrunda
# Processing: 274 of 1000 - Clyde River
# Processing: 275 of 1000 - Bilma
# Processing: 276 of 1000 - Leshukonskoye
# Processing: 277 of 1000 - Souillac
# Processing: 278 of 1000 - Toungoo
#    Unable to get weather information for city: Toungoo
# Processing: 279 of 1000 - Tual
# Processing: 280 of 1000 - Santa Cruz De La Palma
# Processing: 281 of 1000 - Kanigiri
# Processing: 282 of 1000 - Griffith
# Processing: 283 of 1000 - Zhigansk
# Processing: 284 of 1000 - Namibe
# Processing: 285 of 1000 - Thompson
# Processing: 286 of 1000 - Ponta Delgada
# Processing: 287 of 1000 - Nanakuli
# Processing: 288 of 1000 - Soe
# Processing: 289 of 1000 - Maceio
# Processing: 290 of 1000 - Kichera
# Processing: 291 of 1000 - Dieppe Bay
#    Unable to get weather information for city: Dieppe Bay
# Processing: 292 of 1000 - Mnogovershinnyy
# Processing: 293 of 1000 - Vila Franca Do Campo
# Processing: 294 of 1000 - Cedar City
# Processing: 295 of 1000 - Lafiagi
# Processing: 296 of 1000 - Krasnoarmeysk
# Processing: 297 of 1000 - Vardo
# Processing: 298 of 1000 - Ust-Kamchatsk
#    Unable to get weather information for city: Ust-Kamchatsk
# Processing: 299 of 1000 - Olga
# Processing: 300 of 1000 - Atbasar
# Processing: 301 of 1000 - Tambacounda
# Processing: 302 of 1000 - Erenhot
# Processing: 303 of 1000 - Manado
# Processing: 304 of 1000 - Morgan City
# Processing: 305 of 1000 - Esperance
# Processing: 306 of 1000 - Namatanai
# Processing: 307 of 1000 - Bandarbeyla
# Processing: 308 of 1000 - Kasongo-Lunda
# Processing: 309 of 1000 - Antsohihy
# Processing: 310 of 1000 - Forbesganj
# Processing: 311 of 1000 - Guangshui
# Processing: 312 of 1000 - Iqaluit
# Processing: 313 of 1000 - Leningradskiy
# Processing: 314 of 1000 - Maxixe
# Processing: 315 of 1000 - Makakilo City
# Processing: 316 of 1000 - Bazarnyy Syzgan
# Processing: 317 of 1000 - Alihe
# Processing: 318 of 1000 - Xuddur
# Processing: 319 of 1000 - Yellowknife
# Processing: 320 of 1000 - Samusu
#    Unable to get weather information for city: Samusu
# Processing: 321 of 1000 - Tabiauea
#    Unable to get weather information for city: Tabiauea
# Processing: 322 of 1000 - Tessalit
# Processing: 323 of 1000 - Faya
# Processing: 324 of 1000 - Katakwi
# Processing: 325 of 1000 - Alofi
# Processing: 326 of 1000 - Chifeng
# Processing: 327 of 1000 - Khuzhir
# Processing: 328 of 1000 - Beringovskiy
# Processing: 329 of 1000 - Gayeri
# Processing: 330 of 1000 - Pevek
# Processing: 331 of 1000 - Miri
# Processing: 332 of 1000 - Port Augusta
# Processing: 333 of 1000 - Ust-Kulom
# Processing: 334 of 1000 - Sabzevar
# Processing: 335 of 1000 - Dunedin
# Processing: 336 of 1000 - Lesosibirsk
# Processing: 337 of 1000 - Shahr-E Babak
# Processing: 338 of 1000 - Ancud
# Processing: 339 of 1000 - Kokopo
# Processing: 340 of 1000 - Mount Isa
# Processing: 341 of 1000 - Olafsvik
#    Unable to get weather information for city: Olafsvik
# Processing: 342 of 1000 - Xiangfan
#    Unable to get weather information for city: Xiangfan
# Processing: 343 of 1000 - Sabang
# Processing: 344 of 1000 - Santa Isabel Do Rio Negro
# Processing: 345 of 1000 - Lindsay
# Processing: 346 of 1000 - Prainha
# Processing: 347 of 1000 - Paamiut
# Processing: 348 of 1000 - Helong
# Processing: 349 of 1000 - Farah
# Processing: 350 of 1000 - Ijaki
#    Unable to get weather information for city: Ijaki
# Processing: 351 of 1000 - Minot
# Processing: 352 of 1000 - Oktyabrskoye
# Processing: 353 of 1000 - Gurupi
# Processing: 354 of 1000 - Attawapiskat
#    Unable to get weather information for city: Attawapiskat
# Processing: 355 of 1000 - Cherskiy
# Processing: 356 of 1000 - San Pedro
# Processing: 357 of 1000 - Eyl
# Processing: 358 of 1000 - Ust-Omchug
# Processing: 359 of 1000 - Conakry
# Processing: 360 of 1000 - Roma
# Processing: 361 of 1000 - Luau
# Processing: 362 of 1000 - Toyooka
# Processing: 363 of 1000 - Neuquen
# Processing: 364 of 1000 - Broome
# Processing: 365 of 1000 - Rincon
# Processing: 366 of 1000 - Klaksvik
# Processing: 367 of 1000 - Hualmay
# Processing: 368 of 1000 - Chimbote
# Processing: 369 of 1000 - West Lorne
# Processing: 370 of 1000 - San Rafael Del Sur
# Processing: 371 of 1000 - Sierpc
# Processing: 372 of 1000 - Flinders
# Processing: 373 of 1000 - Quatre Cocos
# Processing: 374 of 1000 - Sabha
# Processing: 375 of 1000 - Aripuana
# Processing: 376 of 1000 - Dohrighat
# Processing: 377 of 1000 - Umzimvubu
#    Unable to get weather information for city: Umzimvubu
# Processing: 378 of 1000 - Cowra
# Processing: 379 of 1000 - Dingle
# Processing: 380 of 1000 - Mont-Joli
# Processing: 381 of 1000 - Marzuq
# Processing: 382 of 1000 - Hamilton
# Processing: 383 of 1000 - Arrecife
#    Unable to get weather information for city: Arrecife
# Processing: 384 of 1000 - Belaya Gora
# Processing: 385 of 1000 - Okha
# Processing: 386 of 1000 - Naze
# Processing: 387 of 1000 - Tlaxiaco
#    Unable to get weather information for city: Tlaxiaco
# Processing: 388 of 1000 - Tekkali
# Processing: 389 of 1000 - Nuuk
# Processing: 390 of 1000 - Cockburn Town
# Processing: 391 of 1000 - Aldona
# Processing: 392 of 1000 - Bur Gabo
#    Unable to get weather information for city: Bur Gabo
# Processing: 393 of 1000 - Belyy Yar
# Processing: 394 of 1000 - Ixtapa
# Processing: 395 of 1000 - Chitral
# Processing: 396 of 1000 - Egvekinot
# Processing: 397 of 1000 - North Bend
# Processing: 398 of 1000 - Grand Gaube
# Processing: 399 of 1000 - Chimoio
# Processing: 400 of 1000 - Campobasso
# Processing: 401 of 1000 - Mehamn
# Processing: 402 of 1000 - Hervey Bay
# Processing: 403 of 1000 - Ugoofaaru
# Processing: 404 of 1000 - Nefteyugansk
# Processing: 405 of 1000 - Scottsburgh
#    Unable to get weather information for city: Scottsburgh
# Processing: 406 of 1000 - The Valley
# Processing: 407 of 1000 - Najran
# Processing: 408 of 1000 - Norman Wells
# Processing: 409 of 1000 - Zonguldak
# Processing: 410 of 1000 - Port Macquarie
# Processing: 411 of 1000 - Adeje
# Processing: 412 of 1000 - Wladyslawowo
# Processing: 413 of 1000 - Kalengwa
# Processing: 414 of 1000 - Yangambi
# Processing: 415 of 1000 - Fairbanks
# Processing: 416 of 1000 - Kodinar
# Processing: 417 of 1000 - Kudahuvadhoo
# Processing: 418 of 1000 - Marawi
# Processing: 419 of 1000 - Clonakilty
# Processing: 420 of 1000 - Ravar
# Processing: 421 of 1000 - Haapu
#    Unable to get weather information for city: Haapu
# Processing: 422 of 1000 - Dorado
# Processing: 423 of 1000 - Yuzhno-Sukhokumsk
# Processing: 424 of 1000 - Carbonia
# Processing: 425 of 1000 - Tommot
# Processing: 426 of 1000 - Manavgat
# Processing: 427 of 1000 - Gat
# Processing: 428 of 1000 - General Roca
# Processing: 429 of 1000 - Umm Lajj
# Processing: 430 of 1000 - Malindi
# Processing: 431 of 1000 - Orlik
# Processing: 432 of 1000 - Waitara
# Processing: 433 of 1000 - Ilorin
# Processing: 434 of 1000 - Soledad
# Processing: 435 of 1000 - Butembo
# Processing: 436 of 1000 - Dwarka
# Processing: 437 of 1000 - Bethanien
# Processing: 438 of 1000 - Karaul
#    Unable to get weather information for city: Karaul
# Processing: 439 of 1000 - Gushikawa
# Processing: 440 of 1000 - Ilebo
# Processing: 441 of 1000 - Westport
# Processing: 442 of 1000 - Mecca
# Processing: 443 of 1000 - Coquimbo
# Processing: 444 of 1000 - Ewa Beach
# Processing: 445 of 1000 - Novovelichkovskaya
# Processing: 446 of 1000 - Kavieng
# Processing: 447 of 1000 - Goundam
# Processing: 448 of 1000 - Harper
# Processing: 449 of 1000 - Sorland
# Processing: 450 of 1000 - Abu Samrah
# Processing: 451 of 1000 - Rodrigues Alves
# Processing: 452 of 1000 - Pitimbu
# Processing: 453 of 1000 - Mys Shmidta
#    Unable to get weather information for city: Mys Shmidta
# Processing: 454 of 1000 - Kamaishi
# Processing: 455 of 1000 - Jining
# Processing: 456 of 1000 - Auki
# Processing: 457 of 1000 - Ouadda
# Processing: 458 of 1000 - Mitchell
# Processing: 459 of 1000 - Hovd
# Processing: 460 of 1000 - Gorontalo
# Processing: 461 of 1000 - Albanel
# Processing: 462 of 1000 - Channahon
# Processing: 463 of 1000 - Margate
# Processing: 464 of 1000 - Warrnambool
# Processing: 465 of 1000 - Sao Joao Da Barra
# Processing: 466 of 1000 - Leh
# Processing: 467 of 1000 - Umm Kaddadah
# Processing: 468 of 1000 - Dalby
# Processing: 469 of 1000 - Krasnogorskiy
# Processing: 470 of 1000 - Mackay
# Processing: 471 of 1000 - Uruguaiana
# Processing: 472 of 1000 - Shkotovo-26
#    Unable to get weather information for city: Shkotovo-26
# Processing: 473 of 1000 - Tignere
# Processing: 474 of 1000 - Yar-Sale
# Processing: 475 of 1000 - Tondano
# Processing: 476 of 1000 - Niny
# Processing: 477 of 1000 - Waiuku
# Processing: 478 of 1000 - Lages
# Processing: 479 of 1000 - Tabukiniberu
#    Unable to get weather information for city: Tabukiniberu
# Processing: 480 of 1000 - Alekseyevsk
# Processing: 481 of 1000 - Jalu
# Processing: 482 of 1000 - Havre-Saint-Pierre
# Processing: 483 of 1000 - Palabuhanratu
#    Unable to get weather information for city: Palabuhanratu
# Processing: 484 of 1000 - Akonolinga
# Processing: 485 of 1000 - Saint Anthony
# Processing: 486 of 1000 - Big Bend
# Processing: 487 of 1000 - Rocha
# Processing: 488 of 1000 - Krasnyye Baki
# Processing: 489 of 1000 - Pilao Arcado
#    Unable to get weather information for city: Pilao Arcado
# Processing: 490 of 1000 - Satitoa
#    Unable to get weather information for city: Satitoa
# Processing: 491 of 1000 - Terme
# Processing: 492 of 1000 - Antofagasta
# Processing: 493 of 1000 - Hobyo
# Processing: 494 of 1000 - Cascais
# Processing: 495 of 1000 - Port-Gentil
# Processing: 496 of 1000 - Zhangjiakou
# Processing: 497 of 1000 - Mariental
# Processing: 498 of 1000 - Chicama
# Processing: 499 of 1000 - Cabinda
# Processing: 500 of 1000 - Yomitan
#    Unable to get weather information for city: Yomitan
# Processing: 501 of 1000 - Alfred
# Processing: 502 of 1000 - Alugan
# Processing: 503 of 1000 - Vilyuysk
# Processing: 504 of 1000 - Rolla
# Processing: 505 of 1000 - Vestmannaeyjar
# Processing: 506 of 1000 - Bambanglipuro
# Processing: 507 of 1000 - Pisco
# Processing: 508 of 1000 - Dumai
# Processing: 509 of 1000 - Fredericksburg
# Processing: 510 of 1000 - Tamsweg
# Processing: 511 of 1000 - Ulaanbaatar
# Processing: 512 of 1000 - Riyadh
# Processing: 513 of 1000 - Mrirt
#    Unable to get weather information for city: Mrirt
# Processing: 514 of 1000 - Chiang Klang
# Processing: 515 of 1000 - Nizhneudinsk
# Processing: 516 of 1000 - Siwana
# Processing: 517 of 1000 - Brazzaville
# Processing: 518 of 1000 - Suhbaatar
# Processing: 519 of 1000 - Katsiveli
#    Unable to get weather information for city: Katsiveli
# Processing: 520 of 1000 - Sambava
# Processing: 521 of 1000 - Santa
# Processing: 522 of 1000 - Te Anau
# Processing: 523 of 1000 - Samarai
# Processing: 524 of 1000 - Taoudenni
# Processing: 525 of 1000 - Toktogul
# Processing: 526 of 1000 - Panukulan
# Processing: 527 of 1000 - Verkhnevilyuysk
# Processing: 528 of 1000 - Fortuna
# Processing: 529 of 1000 - Louisbourg
#    Unable to get weather information for city: Louisbourg
# Processing: 530 of 1000 - Qui Nhon
#    Unable to get weather information for city: Qui Nhon
# Processing: 531 of 1000 - Laguna
# Processing: 532 of 1000 - Leeton
# Processing: 533 of 1000 - Praia Da Vitoria
# Processing: 534 of 1000 - Merke
# Processing: 535 of 1000 - Bowmore
# Processing: 536 of 1000 - Villa Del Rosario
# Processing: 537 of 1000 - Saint George
# Processing: 538 of 1000 - Luderitz
# Processing: 539 of 1000 - Sur
# Processing: 540 of 1000 - Mana
# Processing: 541 of 1000 - Coahuayana
# Processing: 542 of 1000 - Kinango
# Processing: 543 of 1000 - Moulins
# Processing: 544 of 1000 - Anadyr
# Processing: 545 of 1000 - Nehe
# Processing: 546 of 1000 - Kisaran
# Processing: 547 of 1000 - Panjab
# Processing: 548 of 1000 - Babanusah
#    Unable to get weather information for city: Babanusah
# Processing: 549 of 1000 - Ust-Tsilma
# Processing: 550 of 1000 - Touros
# Processing: 551 of 1000 - Comodoro Rivadavia
# Processing: 552 of 1000 - Waingapu
# Processing: 553 of 1000 - Norilsk
# Processing: 554 of 1000 - Rantepao
# Processing: 555 of 1000 - Svetlaya
# Processing: 556 of 1000 - Talavera De La Reina
# Processing: 557 of 1000 - Kamenskoye
#    Unable to get weather information for city: Kamenskoye
# Processing: 558 of 1000 - Paso De Carrasco
# Processing: 559 of 1000 - Santa Maria
# Processing: 560 of 1000 - Suez
# Processing: 561 of 1000 - Nixa
# Processing: 562 of 1000 - Nishihara
# Processing: 563 of 1000 - Svetlogorsk
# Processing: 564 of 1000 - Jega
# Processing: 565 of 1000 - Nyurba
# Processing: 566 of 1000 - Vao
# Processing: 567 of 1000 - Denpasar
# Processing: 568 of 1000 - Necochea
# Processing: 569 of 1000 - Ahipara
# Processing: 570 of 1000 - Shiojiri
# Processing: 571 of 1000 - Les Cayes
# Processing: 572 of 1000 - Dubki
# Processing: 573 of 1000 - Pimenta Bueno
# Processing: 574 of 1000 - Smithers
# Processing: 575 of 1000 - Saint-Pierre
# Processing: 576 of 1000 - Buarcos
# Processing: 577 of 1000 - Guerrero Negro
# Processing: 578 of 1000 - Gamba
# Processing: 579 of 1000 - Nantucket
# Processing: 580 of 1000 - Brigantine
# Processing: 581 of 1000 - Victoria Point
# Processing: 582 of 1000 - Muriwai Beach
# Processing: 583 of 1000 - Ayna
# Processing: 584 of 1000 - Taywarah
# Processing: 585 of 1000 - Mantsala
# Processing: 586 of 1000 - Crixas
# Processing: 587 of 1000 - Fushun
# Processing: 588 of 1000 - Pangnirtung
# Processing: 589 of 1000 - Ilulissat
# Processing: 590 of 1000 - Straseni
# Processing: 591 of 1000 - Dayong
# Processing: 592 of 1000 - Karkaralinsk
#    Unable to get weather information for city: Karkaralinsk
# Processing: 593 of 1000 - Xihua
# Processing: 594 of 1000 - Vagur
# Processing: 595 of 1000 - Baykit
# Processing: 596 of 1000 - Bara
# Processing: 597 of 1000 - Diamantino
# Processing: 598 of 1000 - Izumo
# Processing: 599 of 1000 - Ridgecrest
# Processing: 600 of 1000 - Havre
# Processing: 601 of 1000 - Franklin
# Processing: 602 of 1000 - San Quintin
# Processing: 603 of 1000 - Guatire
# Processing: 604 of 1000 - Pussi
# Processing: 605 of 1000 - Xining
# Processing: 606 of 1000 - Ibra
# Processing: 607 of 1000 - Grado
# Processing: 608 of 1000 - Xichang
# Processing: 609 of 1000 - Burgeo
# Processing: 610 of 1000 - Abonnema
# Processing: 611 of 1000 - Henties Bay
# Processing: 612 of 1000 - Montreal
# Processing: 613 of 1000 - Jyvaskyla
#    Unable to get weather information for city: Jyvaskyla
# Processing: 614 of 1000 - Avera
# Processing: 615 of 1000 - Plettenberg Bay
# Processing: 616 of 1000 - Obihiro
# Processing: 617 of 1000 - Usevya
#    Unable to get weather information for city: Usevya
# Processing: 618 of 1000 - Ushibuka
# Processing: 619 of 1000 - Boende
# Processing: 620 of 1000 - Honningsvag
# Processing: 621 of 1000 - Cockburn Harbour
#    Unable to get weather information for city: Cockburn Harbour
# Processing: 622 of 1000 - Chokurdakh
# Processing: 623 of 1000 - Shu
# Processing: 624 of 1000 - Kattivakkam
# Processing: 625 of 1000 - Sokolo
# Processing: 626 of 1000 - Sobolevo
# Processing: 627 of 1000 - Rorvik
# Processing: 628 of 1000 - Tecoanapa
# Processing: 629 of 1000 - Sendafa
# Processing: 630 of 1000 - Ambam
# Processing: 631 of 1000 - Nemuro
# Processing: 632 of 1000 - Severnoye
# Processing: 633 of 1000 - Dakar
# Processing: 634 of 1000 - Veraval
# Processing: 635 of 1000 - Reo
# Processing: 636 of 1000 - Shache
# Processing: 637 of 1000 - La Libertad
# Processing: 638 of 1000 - Hvammstangi
#    Unable to get weather information for city: Hvammstangi
# Processing: 639 of 1000 - Kargasok
# Processing: 640 of 1000 - Tilichiki
# Processing: 641 of 1000 - Tanout
# Processing: 642 of 1000 - Biak
# Processing: 643 of 1000 - Lazaro Cardenas
# Processing: 644 of 1000 - Taitung
# Processing: 645 of 1000 - Hargeysa
# Processing: 646 of 1000 - Morondava
# Processing: 647 of 1000 - Mercedes
# Processing: 648 of 1000 - Suntar
# Processing: 649 of 1000 - Staraya Kulatka
# Processing: 650 of 1000 - Imeni Stepana Razina
# Processing: 651 of 1000 - Port Blair
# Processing: 652 of 1000 - Saint-Francois
# Processing: 653 of 1000 - Mareeba
# Processing: 654 of 1000 - Nguiu
#    Unable to get weather information for city: Nguiu
# Processing: 655 of 1000 - Yuli
# Processing: 656 of 1000 - Novikovo
# Processing: 657 of 1000 - Santa Fe
# Processing: 658 of 1000 - Deputatskiy
# Processing: 659 of 1000 - Hatillo
# Processing: 660 of 1000 - Zakamensk
# Processing: 661 of 1000 - Kundiawa
# Processing: 662 of 1000 - Iskateley
# Processing: 663 of 1000 - Visnes
# Processing: 664 of 1000 - Hailar
# Processing: 665 of 1000 - Sakhipur
# Processing: 666 of 1000 - Soyo
# Processing: 667 of 1000 - Cileunyi
# Processing: 668 of 1000 - Calabozo
# Processing: 669 of 1000 - Viedma
# Processing: 670 of 1000 - Chaoyang
# Processing: 671 of 1000 - Rudnogorsk
# Processing: 672 of 1000 - Tiarei
# Processing: 673 of 1000 - Kambove
# Processing: 674 of 1000 - Kihei
# Processing: 675 of 1000 - Doctor Pedro P. Pena
#    Unable to get weather information for city: Doctor Pedro P. Pena
# Processing: 676 of 1000 - Sioux Lookout
# Processing: 677 of 1000 - Chagda
#    Unable to get weather information for city: Chagda
# Processing: 678 of 1000 - Ndele
#    Unable to get weather information for city: Ndele
# Processing: 679 of 1000 - Pinega
# Processing: 680 of 1000 - Turayf
# Processing: 681 of 1000 - Lungi
# Processing: 682 of 1000 - Qaqortoq
# Processing: 683 of 1000 - Valley Station
# Processing: 684 of 1000 - Monster
# Processing: 685 of 1000 - Adrar
# Processing: 686 of 1000 - Dashitou
# Processing: 687 of 1000 - Melhus
# Processing: 688 of 1000 - Rio Gallegos
# Processing: 689 of 1000 - Homer
# Processing: 690 of 1000 - Bera
# Processing: 691 of 1000 - Miandrivazo
# Processing: 692 of 1000 - Saint-Leu
# Processing: 693 of 1000 - Buin
# Processing: 694 of 1000 - Moose Factory
# Processing: 695 of 1000 - Jiblah
# Processing: 696 of 1000 - Goderich
# Processing: 697 of 1000 - Ruatoria
#    Unable to get weather information for city: Ruatoria
# Processing: 698 of 1000 - Mega
# Processing: 699 of 1000 - Alepe
# Processing: 700 of 1000 - Dawei
# Processing: 701 of 1000 - Coolum Beach
# Processing: 702 of 1000 - Moranbah
# Processing: 703 of 1000 - Khilok
# Processing: 704 of 1000 - Fevralsk
#    Unable to get weather information for city: Fevralsk
# Processing: 705 of 1000 - Tura
# Processing: 706 of 1000 - Coihaique
# Processing: 707 of 1000 - Sao Felix Do Xingu
# Processing: 708 of 1000 - Kitimat
# Processing: 709 of 1000 - Portland
# Processing: 710 of 1000 - Pilar
# Processing: 711 of 1000 - Excelsior Springs
# Processing: 712 of 1000 - Manokwari
# Processing: 713 of 1000 - Ambunti
# Processing: 714 of 1000 - Rameshki
# Processing: 715 of 1000 - Baza
# Processing: 716 of 1000 - Borovoy
# Processing: 717 of 1000 - Saurimo
# Processing: 718 of 1000 - Karwar
# Processing: 719 of 1000 - Sentyabrskiy
#    Unable to get weather information for city: Sentyabrskiy
# Processing: 720 of 1000 - Pemberton
# Processing: 721 of 1000 - Caldas Novas
# Processing: 722 of 1000 - Imbituba
# Processing: 723 of 1000 - Turukhansk
# Processing: 724 of 1000 - Porto Novo
# Processing: 725 of 1000 - Toliary
#    Unable to get weather information for city: Toliary
# Processing: 726 of 1000 - Meulaboh
# Processing: 727 of 1000 - Tanta
# Processing: 728 of 1000 - Monte Patria
# Processing: 729 of 1000 - Paita
# Processing: 730 of 1000 - Hubli
# Processing: 731 of 1000 - Maldonado
# Processing: 732 of 1000 - Nizwa
# Processing: 733 of 1000 - Ginir
# Processing: 734 of 1000 - Senmonorom
#    Unable to get weather information for city: Senmonorom
# Processing: 735 of 1000 - Koslan
# Processing: 736 of 1000 - Matagami
# Processing: 737 of 1000 - Bolshoy Tsaryn
#    Unable to get weather information for city: Bolshoy Tsaryn
# Processing: 738 of 1000 - Shenjiamen
# Processing: 739 of 1000 - Daru
# Processing: 740 of 1000 - Poum
# Processing: 741 of 1000 - Kolyshley
# Processing: 742 of 1000 - Laiagam
#    Unable to get weather information for city: Laiagam
# Processing: 743 of 1000 - Swellendam
# Processing: 744 of 1000 - Eureka
# Processing: 745 of 1000 - Beaverlodge
# Processing: 746 of 1000 - Smolenka
# Processing: 747 of 1000 - Sfantu Gheorghe
# Processing: 748 of 1000 - Tsienyane
#    Unable to get weather information for city: Tsienyane
# Processing: 749 of 1000 - Kidal
# Processing: 750 of 1000 - Sorvag
#    Unable to get weather information for city: Sorvag
# Processing: 751 of 1000 - Cedeno
# Processing: 752 of 1000 - Noyabrsk
# Processing: 753 of 1000 - Pueblo Nuevo
# Processing: 754 of 1000 - Saint-Augustin
# Processing: 755 of 1000 - Kollam
# Processing: 756 of 1000 - Khor
# Processing: 757 of 1000 - Brainerd
# Processing: 758 of 1000 - Tolaga Bay
# Processing: 759 of 1000 - Kon Tum
# Processing: 760 of 1000 - Chota
# Processing: 761 of 1000 - Amuntai
# Processing: 762 of 1000 - Sopelana
# Processing: 763 of 1000 - Kazanskoye
#    Unable to get weather information for city: Kazanskoye
# Processing: 764 of 1000 - Canandaigua
# Processing: 765 of 1000 - Aksarka
# Processing: 766 of 1000 - New Iberia
# Processing: 767 of 1000 - Hay River
# Processing: 768 of 1000 - Agadez
# Processing: 769 of 1000 - Khandyga
# Processing: 770 of 1000 - Nieuw Amsterdam
# Processing: 771 of 1000 - Kassala
# Processing: 772 of 1000 - Tromso
# Processing: 773 of 1000 - Kirakira
# Processing: 774 of 1000 - Zyryanka
# Processing: 775 of 1000 - Grosseto
# Processing: 776 of 1000 - Port Hueneme
# Processing: 777 of 1000 - Rio Alejandro
# Processing: 778 of 1000 - Ciudad Guayana
# Processing: 779 of 1000 - Elias Fausto
# Processing: 780 of 1000 - Preobrazheniye
# Processing: 781 of 1000 - Vaitupu
#    Unable to get weather information for city: Vaitupu
# Processing: 782 of 1000 - Tuggurt
#    Unable to get weather information for city: Tuggurt
# Processing: 783 of 1000 - Palampur
# Processing: 784 of 1000 - Pasni
# Processing: 785 of 1000 - Labuan
# Processing: 786 of 1000 - San Juan De Uraba
# Processing: 787 of 1000 - Virginia Beach
# Processing: 788 of 1000 - San Cristobal
# Processing: 789 of 1000 - Mago
# Processing: 790 of 1000 - Kamenka
# Processing: 791 of 1000 - Owando
# Processing: 792 of 1000 - Fare
# Processing: 793 of 1000 - Quimper
# Processing: 794 of 1000 - Mokhsogollokh
# Processing: 795 of 1000 - Atherton
# Processing: 796 of 1000 - Pafos
#    Unable to get weather information for city: Pafos
# Processing: 797 of 1000 - Kachug
# Processing: 798 of 1000 - Am Timan
# Processing: 799 of 1000 - Mithi
# Processing: 800 of 1000 - Red Bluff
# Processing: 801 of 1000 - Yerbogachen
# Processing: 802 of 1000 - Shakiso
# Processing: 803 of 1000 - Sinop
# Processing: 804 of 1000 - Tunxi
#    Unable to get weather information for city: Tunxi
# Processing: 805 of 1000 - Ananas
# Processing: 806 of 1000 - Cabra
# Processing: 807 of 1000 - Bulgan
# Processing: 808 of 1000 - Yaan
# Processing: 809 of 1000 - Mayo
# Processing: 810 of 1000 - Kabul
# Processing: 811 of 1000 - Ambulu
# Processing: 812 of 1000 - Tautira
# Processing: 813 of 1000 - Thohoyandou
# Processing: 814 of 1000 - Sinnamary
# Processing: 815 of 1000 - Shalya
# Processing: 816 of 1000 - Bereda
# Processing: 817 of 1000 - Sangar
# Processing: 818 of 1000 - Guasdualito
# Processing: 819 of 1000 - Dera Din Panah
#    Unable to get weather information for city: Dera Din Panah
# Processing: 820 of 1000 - Urumqi
#    Unable to get weather information for city: Urumqi
# Processing: 821 of 1000 - Sansai
#    Unable to get weather information for city: Sansai
# Processing: 822 of 1000 - Kiunga
# Processing: 823 of 1000 - Fort-Shevchenko
# Processing: 824 of 1000 - Port Lincoln
# Processing: 825 of 1000 - Karaton
# Processing: 826 of 1000 - Gabu
# Processing: 827 of 1000 - Road Town
# Processing: 828 of 1000 - Tanete
# Processing: 829 of 1000 - Safaga
#    Unable to get weather information for city: Safaga
# Processing: 830 of 1000 - Khonuu
#    Unable to get weather information for city: Khonuu
# Processing: 831 of 1000 - Lexington
# Processing: 832 of 1000 - Shingu
# Processing: 833 of 1000 - Barreirinhas
# Processing: 834 of 1000 - Punta Alta
# Processing: 835 of 1000 - Wainwright
# Processing: 836 of 1000 - Bhabua
# Processing: 837 of 1000 - Angoche
# Processing: 838 of 1000 - Zhicheng
# Processing: 839 of 1000 - Ageyevo
# Processing: 840 of 1000 - Asadabad
# Processing: 841 of 1000 - Kashi
#    Unable to get weather information for city: Kashi
# Processing: 842 of 1000 - Harboore
# Processing: 843 of 1000 - Oistins
# Processing: 844 of 1000 - Betanzos
# Processing: 845 of 1000 - Ust-Nera
# Processing: 846 of 1000 - Vicuna
#    Unable to get weather information for city: Vicuna
# Processing: 847 of 1000 - Bud
# Processing: 848 of 1000 - Bouake
# Processing: 849 of 1000 - Kloulklubed
# Processing: 850 of 1000 - Madimba
# Processing: 851 of 1000 - Kifri
# Processing: 852 of 1000 - Bargal
#    Unable to get weather information for city: Bargal
# Processing: 853 of 1000 - Tabuk
# Processing: 854 of 1000 - Porbandar
# Processing: 855 of 1000 - High Level
# Processing: 856 of 1000 - Usinsk
# Processing: 857 of 1000 - Itarema
# Processing: 858 of 1000 - Chioggia
# Processing: 859 of 1000 - Ewo
# Processing: 860 of 1000 - Sao Jose Da Coroa Grande
# Processing: 861 of 1000 - Lincoln
# Processing: 862 of 1000 - Tevaitoa
# Processing: 863 of 1000 - Mentok
#    Unable to get weather information for city: Mentok
# Processing: 864 of 1000 - Atambua
# Processing: 865 of 1000 - Killybegs
# Processing: 866 of 1000 - Hrubieszow
# Processing: 867 of 1000 - Bermeo
# Processing: 868 of 1000 - Ostroleka
# Processing: 869 of 1000 - Parabel
# Processing: 870 of 1000 - Yeniseysk
# Processing: 871 of 1000 - Marsh Harbour
# Processing: 872 of 1000 - Castelnaudary
# Processing: 873 of 1000 - Acarau
#    Unable to get weather information for city: Acarau
# Processing: 874 of 1000 - Altay
# Processing: 875 of 1000 - Kungsbacka
# Processing: 876 of 1000 - Panambi
# Processing: 877 of 1000 - Mocambique
#    Unable to get weather information for city: Mocambique
# Processing: 878 of 1000 - Buriti Bravo
# Processing: 879 of 1000 - Shitkino
# Processing: 880 of 1000 - Babynino
# Processing: 881 of 1000 - Jambi
# Processing: 882 of 1000 - San-Pedro
# Processing: 883 of 1000 - Linfen
# Processing: 884 of 1000 - Rafraf
# Processing: 885 of 1000 - Potsdam
# Processing: 886 of 1000 - Esso
# Processing: 887 of 1000 - Thunder Bay
# Processing: 888 of 1000 - Marcona
#    Unable to get weather information for city: Marcona
# Processing: 889 of 1000 - Ola
# Processing: 890 of 1000 - Boddam
# Processing: 891 of 1000 - Barra Do Pirai
# Processing: 892 of 1000 - Kiama
# Processing: 893 of 1000 - Malisbong
#    Unable to get weather information for city: Malisbong
# Processing: 894 of 1000 - Marv Dasht
#    Unable to get weather information for city: Marv Dasht
# Processing: 895 of 1000 - Ubata
# Processing: 896 of 1000 - Ikongo
# Processing: 897 of 1000 - Chegdomyn
# Processing: 898 of 1000 - Namwala
# Processing: 899 of 1000 - Niksar
# Processing: 900 of 1000 - Luba
# Processing: 901 of 1000 - Dothan
# Processing: 902 of 1000 - Lichuan
# Processing: 903 of 1000 - Hambantota
# Processing: 904 of 1000 - Sinjar
# Processing: 905 of 1000 - Sola
# Processing: 906 of 1000 - Lentate Sul Seveso
# Processing: 907 of 1000 - Constantine
# Processing: 908 of 1000 - Beidao
# Processing: 909 of 1000 - Gazimurskiy Zavod
# Processing: 910 of 1000 - Bubaque
# Processing: 911 of 1000 - Santa Cruz
# Processing: 912 of 1000 - Portobelo
# Processing: 913 of 1000 - Arkhangelos
#    Unable to get weather information for city: Arkhangelos
# Processing: 914 of 1000 - Nanyang
# Processing: 915 of 1000 - Kuruksay
#    Unable to get weather information for city: Kuruksay
# Processing: 916 of 1000 - Sechura
# Processing: 917 of 1000 - Thai Binh
# Processing: 918 of 1000 - Oda
# Processing: 919 of 1000 - Pochutla
# Processing: 920 of 1000 - Kanye
# Processing: 921 of 1000 - Akdepe
# Processing: 922 of 1000 - Hunchun
# Processing: 923 of 1000 - Monrovia
# Processing: 924 of 1000 - Tamandare
# Processing: 925 of 1000 - Hami
# Processing: 926 of 1000 - Upington
# Processing: 927 of 1000 - Jiddah
#    Unable to get weather information for city: Jiddah
# Processing: 928 of 1000 - Ekhabi
# Processing: 929 of 1000 - Bougouni
# Processing: 930 of 1000 - Ostrzeszow
# Processing: 931 of 1000 - Belmonte
# Processing: 932 of 1000 - Muncar
# Processing: 933 of 1000 - Sri Aman
# Processing: 934 of 1000 - Winnemucca
# Processing: 935 of 1000 - Kolokani
# Processing: 936 of 1000 - Wahiawa
# Processing: 937 of 1000 - Ban Dung
# Processing: 938 of 1000 - Esmeraldas
# Processing: 939 of 1000 - Mwinilunga
# Processing: 940 of 1000 - Piranshahr
# Processing: 941 of 1000 - Turrialba
# Processing: 942 of 1000 - Ampanihy
# Processing: 943 of 1000 - Carndonagh
# Processing: 944 of 1000 - Mbekenyera
# Processing: 945 of 1000 - Urdoma
# Processing: 946 of 1000 - Svetlyy
#    Unable to get weather information for city: Svetlyy
# Processing: 947 of 1000 - Kharp
# Processing: 948 of 1000 - Mafinga
#    Unable to get weather information for city: Mafinga
# Processing: 949 of 1000 - Juneau
# Processing: 950 of 1000 - Nueva Gerona
# Processing: 951 of 1000 - Tungor
# Processing: 952 of 1000 - Vyshestebliyevskaya
# Processing: 953 of 1000 - Chilca
# Processing: 954 of 1000 - Kahului
# Processing: 955 of 1000 - Srednekolymsk
# Processing: 956 of 1000 - Yarim
# Processing: 957 of 1000 - Masallatah
# Processing: 958 of 1000 - Krasnoselkup
#    Unable to get weather information for city: Krasnoselkup
# Processing: 959 of 1000 - Padang
# Processing: 960 of 1000 - Cocachacra
# Processing: 961 of 1000 - Suslovo
# Processing: 962 of 1000 - Shepsi
# Processing: 963 of 1000 - Metro
# Processing: 964 of 1000 - Garissa
# Processing: 965 of 1000 - Skelleftea
# Processing: 966 of 1000 - Wanaka
# Processing: 967 of 1000 - Store Heddinge
# Processing: 968 of 1000 - Zhanaozen
# Processing: 969 of 1000 - Petropavlovsk-Kamchatskiy
# Processing: 970 of 1000 - Nioro
# Processing: 971 of 1000 - Kuche
#    Unable to get weather information for city: Kuche
# Processing: 972 of 1000 - Seoul
# Processing: 973 of 1000 - Brae
# Processing: 974 of 1000 - Cartagena Del Chaira
# Processing: 975 of 1000 - Ngukurr
#    Unable to get weather information for city: Ngukurr
# Processing: 976 of 1000 - Bazaliya
# Processing: 977 of 1000 - Songjianghe
# Processing: 978 of 1000 - Biryusinsk
# Processing: 979 of 1000 - Harjavalta
# Processing: 980 of 1000 - Temizhbekskaya
# Processing: 981 of 1000 - Escanaba
# Processing: 982 of 1000 - Mezhdurechensk
# Processing: 983 of 1000 - Tupaciguara
# Processing: 984 of 1000 - Male
# Processing: 985 of 1000 - Chepareria
# Processing: 986 of 1000 - Stokmarknes
# Processing: 987 of 1000 - Guilin
# Processing: 988 of 1000 - Chulym
# Processing: 989 of 1000 - Kolpashevo
# Processing: 990 of 1000 - Morden
# Processing: 991 of 1000 - Eskasem
#    Unable to get weather information for city: Eskasem
# Processing: 992 of 1000 - Lalomanu
#    Unable to get weather information for city: Lalomanu
# Processing: 993 of 1000 - Bida
# Processing: 994 of 1000 - Bowen
# Processing: 995 of 1000 - Hornepayne
# Processing: 996 of 1000 - Sibolga
# Processing: 997 of 1000 - White Rock
# Processing: 998 of 1000 - Calama
# Processing: 999 of 1000 - Putina
# Processing: 1000 of 1000 - Skibbereen
#
# Completed getting data. Total Cities: 902  Error Cities: 98

# %%
#-- Prepare Data For Charting

#- Create Data Frame
weather_df = pd.DataFrame(weatherData)


#- Fix Humidity Values
#  Found at least one record that had invalid humidity % of 290
weather_df.loc[weather_df['Humidity'] > 100, 'Humidity'] = 100


#- Export to csv
exportDataPath = os.path.join(".", "Output", "WeatherData.cvs")

weather_df.to_csv(exportDataPath, encoding='utf-8', index=False)


#- Preview Dataframe
weather_df.head()
# Out:
#         City Country  Latitude  Longitude  Temperature  WindSpeed  Humidity  \
# 0      Kapaa      US     22.08    -159.32        68.00       8.05        72
# 1  Busselton      AU    -33.64     115.35        68.00      21.50        39
# 2      Tabas      IR     33.60      56.92        43.86       5.95        29
# 3      Teeli      RU     51.01      90.20        -0.60       0.58        53
# 4    Vaitape      PF    -16.52    -151.75        82.83       5.06       100
#
#    Cloudiness
# 0          75
# 1           0
# 2           0
# 3           8
# 4          44

# %%
#-- Create Date for Plots
dateInfo = datetime.datetime.now().strftime("%B %-d, %Y")

# %%
#-- Plot Latitude vs Temperature

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Temperature'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Max Temperature ({dateInfo})')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
temperatureImagePath = os.path.join(".", "Output", "LatitudeAndMaxTemperature.png")

plt.savefig(temperatureImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Humidity

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Humidity ({dateInfo})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
humidityImagePath = os.path.join(".", "Output", "LatitudeAndHumidity.png")

plt.savefig(humidityImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Cloudiness

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Cloudiness ({dateInfo})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
cloudinessImagePath = os.path.join(".", "Output", "LatitudeAndCloudiness.png")

plt.savefig(cloudinessImagePath)


#- Show Chart
plt.show()

# %%
#-- Plot Latitude vs Wind Speed

#- Create Plot
plt.figure(figsize = (10, 5))

plt.scatter(weather_df['Latitude'], weather_df['WindSpeed'], marker='o', 
            facecolors='blue', edgecolors='black', alpha= .6)


#- Set Chart Metadata
plt.title(f'City Latitude vs. Wind Speed ({dateInfo})')
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.grid()


#- Save Chart
windImagePath = os.path.join(".", "Output", "LatitudeAndWindSpeed.png")

plt.savefig(windImagePath)


#- Show Chart
plt.show()
